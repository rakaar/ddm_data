# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm
from joblib import Parallel, delayed
from pyvbmc import VBMC
import corner
from psiam_tied_dv_map_utils import rho_A_t_fn, up_RTs_fit_fn, down_RTs_fit_fn, up_RTs_fit_single_t_fn, psiam_tied_data_gen_wrapper, psiam_tied_data_gen_wrapper_V2
import sys
import multiprocessing
from dynesty import NestedSampler
from dynesty import plotting as dyplot
import multiprocessing

# %%
# read out_LED.csv as dataframe
og_df = pd.read_csv('../out_LED.csv')

# %%
# chose non repeat trials - 0 or 2 or missing
df = og_df[ og_df['repeat_trial'].isin([0,2]) | og_df['repeat_trial'].isna() ]

# only session type 7
session_type = 7    
df = df[ df['session_type'].isin([session_type]) ]

# training level 16
training_level = 16
df = df[ df['training_level'].isin([training_level]) ]

# %%
# find ABL and ILD
ABL_arr = df['ABL'].unique()
ILD_arr = df['ILD'].unique()


# sort ILD arr in ascending order
ILD_arr = np.sort(ILD_arr)
ABL_arr = np.sort(ABL_arr)

print('ABL:', ABL_arr)
print('ILD:', ILD_arr)
# Out:
# ABL: [20 40 60]
# ILD: [-16.  -8.  -4.  -2.  -1.   1.   2.   4.   8.  16.]

# %%
# LED off rows
df_1 = df[ df['LED_trial'] == 0 ]
df_1 = df_1[ df_1['timed_fix'] > df_1['intended_fix'] ]

# %%
import pickle
with open('../fitting_aborts/post_led_censor_test_vbmc.pkl', 'rb') as f:
    vp = pickle.load(f)

# %%
vp_sample = vp.sample(int(1e6))[0]

# %%
V_A = np.mean(vp_sample[:,0])
theta_A = np.mean(vp_sample[:,1])
t_motor = 0.04
t_A_aff = np.mean(vp_sample[:,2]) - t_motor
# t_A_aff = 0.05 # NOTE: TEMP, to test if negative afferent delay is causing VBMC to not converge

# %%
t_A_aff
# Out:
# np.float64(-0.22652353549137394)

# %% [markdown]
# # VBMC

# %% [markdown]
# ## loglike fn

# %%
def compute_loglike(row, rate_lambda, T_0, theta_E, t_E_aff, Z_E, L):
    timed_fix = row['timed_fix']
    intended_fix = row['intended_fix']
    
    ILD = row['ILD']
    ABL = row['ABL']
    choice = row['response_poke']

    rt = timed_fix
    t_stim = intended_fix
    
    K_max = 10

    if choice == 3:
        likelihood = up_RTs_fit_fn([rt], V_A, theta_A, ABL, ILD, rate_lambda, T_0, \
                                    theta_E, Z_E, t_stim, t_A_aff, t_E_aff, t_motor, L, K_max)[0]
    elif choice == 2:
        likelihood = down_RTs_fit_fn([rt], V_A, theta_A, ABL, ILD, rate_lambda, T_0,\
                                        theta_E, Z_E, t_stim, t_A_aff, t_E_aff, t_motor, L, K_max)[0]


    if likelihood <= 0:
        likelihood = 1e-50

    
    return np.log(likelihood)    


def psiam_tied_loglike_fn(params):
    rate_lambda, T_0, theta_E, t_E_aff, Z_E, L = params


    all_loglike = Parallel(n_jobs=30)(delayed(compute_loglike)(row, rate_lambda, T_0, theta_E, t_E_aff, Z_E, L)\
                                       for _, row in df_1.iterrows() if (row['timed_fix'] > row['intended_fix']) \
                                        and (row['response_poke'] in [2,3]))

    loglike = np.sum(all_loglike)
    return loglike

# %%
def dynesty_psiam_tied_loglike_fn(params):
    rate_lambda, T_0, theta_E, t_E_aff, Z_E, L = params
    
    # Filter DataFrame rows first
    filtered_rows = df_1.loc[
        (df_1['timed_fix'] > df_1['intended_fix']) &
        (df_1['response_poke'].isin([2, 3]))
    ]
    
    # Prepare arguments for each row
    # We'll map over just the row data. The other parameters are closed over
    # from the outer scope.
    row_data = [row for _, row in filtered_rows.iterrows()]

    # Use multiprocessing Pool
    # You can adjust processes=30 to however many processes you need
    all_loglike = np.array([compute_loglike(row, rate_lambda, T_0, theta_E, t_E_aff, Z_E, L) for row in row_data])

    # Sum the log-likelihoods
    loglike = np.sum(all_loglike)

    # If loglike is inf or -inf or nan, return log(1e-50)
    if np.isnan(loglike) or np.isinf(loglike):
        return np.log(1e-50)
    else:
        return loglike

# %% [markdown]
# ## Bounds

# %%
rate_lambda_bounds = [0.01, 0.2]
theta_E_bounds = [30, 60]
T_0_bounds = [0.1*(1e-3), 1*(1e-3)]


t_E_aff_bounds = [0.001, 0.1]
Z_E_bounds = [-10, 10]
L_bounds = [0.1, 1.99]

# ---
rate_lambda_plausible_bounds =  [0.05, 0.09]
T_0_plausible_bounds = [0.15*(1e-3), 0.5*(1e-3)]
theta_E_plausible_bounds = [40, 55]

t_E_aff_plausible_bounds = [0.01, 0.05]
Z_E_plausible_bounds = [-5, 5]
L_plausible_bounds = [0.5, 1.5]

# %% [markdown]
# ## prior

# %%
# def trapezoidal_logpdf(x, a, b, c, d):
#     if x < a or x > d:
#         return -np.inf  # Logarithm of zero
#     area = ((b - a) + (d - c)) / 2 + (c - b)
#     h_max = 1.0 / area  # Height of the trapezoid to normalize the area to 1
    
#     if a <= x <= b:
#         pdf_value = ((x - a) / (b - a)) * h_max
#     elif b < x < c:
#         pdf_value = h_max
#     elif c <= x <= d:
#         pdf_value = ((d - x) / (d - c)) * h_max
#     else:
#         pdf_value = 0.0  # This case is redundant due to the initial check

#     if pdf_value <= 0.0:
#         return -np.inf
#     else:
#         return np.log(pdf_value)
    

# def psiam_tied_prior_fn(params):
#     rate_lambda, T_0, theta_E, t_E_aff, Z_E, L = params

#     rate_lambda_logpdf = trapezoidal_logpdf(rate_lambda, rate_lambda_bounds[0], rate_lambda_plausible_bounds[0], rate_lambda_plausible_bounds[1], rate_lambda_bounds[1])
#     theta_E_logpdf = trapezoidal_logpdf(theta_E, theta_E_bounds[0], theta_E_plausible_bounds[0], theta_E_plausible_bounds[1], theta_E_bounds[1])
#     T_0_logpdf = trapezoidal_logpdf(T_0, T_0_bounds[0], T_0_plausible_bounds[0], T_0_plausible_bounds[1], T_0_bounds[1])
    
#     t_E_aff_logpdf = trapezoidal_logpdf(t_E_aff, t_E_aff_bounds[0], t_E_aff_plausible_bounds[0], t_E_aff_plausible_bounds[1], t_E_aff_bounds[1])
#     Z_E_logpdf = trapezoidal_logpdf(Z_E, Z_E_bounds[0], Z_E_plausible_bounds[0], Z_E_plausible_bounds[1], Z_E_bounds[1])
#     L_logpdf = trapezoidal_logpdf(L, L_bounds[0], L_plausible_bounds[0], L_plausible_bounds[1], L_bounds[1])

#     return rate_lambda_logpdf + T_0_logpdf + theta_E_logpdf + t_E_aff_logpdf + Z_E_logpdf + L_logpdf



# --------------------------------------------------
# Example: define means and correlation for (lambda, T0, theta_E)
# --------------------------------------------------

# Example means for each param (could be midpoints of plausible intervals, or domain knowledge)
lambda_mean   = 0.5 * (rate_lambda_plausible_bounds[0] + rate_lambda_plausible_bounds[1])
T0_mean       = 0.5 * (T_0_plausible_bounds[0]        + T_0_plausible_bounds[1])
theta_E_mean  = 0.5 * (theta_E_plausible_bounds[0]    + theta_E_plausible_bounds[1])
mu = np.array([lambda_mean, T0_mean, theta_E_mean])

# Example standard deviations for each param
sigma_lambda  = (rate_lambda_plausible_bounds[1] - rate_lambda_plausible_bounds[0]) / 4.0
sigma_T0      = (T_0_plausible_bounds[1]         - T_0_plausible_bounds[0])         / 4.0
sigma_theta_E = (theta_E_plausible_bounds[1]     - theta_E_plausible_bounds[0])     / 4.0

# Desired correlation coefficients:
#   Corr(lambda, T0) = +0.5
#   Corr(lambda, theta_E) = -0.3
#   Corr(T0, theta_E) = -0.3
corr_lambda_T0    =  0.95
corr_lambda_theta = -0.95
corr_T0_theta     = -0.95

# Build the correlation matrix
#  C[i, j] = correlation(i, j)
C = np.array([
    [1.0,               corr_lambda_T0,    corr_lambda_theta],
    [corr_lambda_T0,    1.0,               corr_T0_theta],
    [corr_lambda_theta, corr_T0_theta,     1.0]
])

# Convert correlation matrix to covariance matrix by scaling with sigmas:
D = np.diag([sigma_lambda, sigma_T0, sigma_theta_E])
Sigma = D @ C @ D  # covariance = diag(sigmas) * correlation * diag(sigmas)

# Precompute inverse and logdet for speed
Sigma_inv = np.linalg.inv(Sigma)
logdet_Sigma = np.log(np.linalg.det(Sigma))
dim = 3  # since we have three correlated parameters

def logpdf_correlated_lambda_T0_thetaE(x_vec):
    """
    x_vec = [lambda, T0, theta_E]
    Returns log of multivariate normal restricted to the bounding box
    that matches the 'trapezoid domain'.
    """
    # 1) Check bounding box to enforce "hard" bounds
    lam, T0, thE = x_vec

    if (lam < rate_lambda_bounds[0]) or (lam > rate_lambda_bounds[1]):
        return np.log(1e-50)
    if (T0 < T_0_bounds[0]) or (T0 > T_0_bounds[1]):
        return np.log(1e-50)
    if (thE < theta_E_bounds[0]) or (thE > theta_E_bounds[1]):
        return np.log(1e-50)

    # 2) Evaluate the log of the multivariate normal
    dx = x_vec - mu
    # Mahalanobis distance
    mahala = dx @ Sigma_inv @ dx
    # logpdf of MVN (without normalization if out of box)
    logpdf = -0.5 * (mahala + dim * np.log(2.0 * np.pi) + logdet_Sigma)
    return logpdf

# --------------------------------------------------
# Keep the other parameters with their trapezoid priors
# --------------------------------------------------

def trapezoidal_logpdf(x, a, b, c, d):
    """
    Same trapezoid PDF, returning log(pdf).  If out of range, -inf.
    """
    if x < a or x > d:
        return -np.inf
    
    area = ((b - a) + (d - c)) / 2 + (c - b)
    h_max = 1.0 / area  # Height for normalization

    if a <= x <= b:
        pdf_value = ((x - a) / (b - a)) * h_max
    elif b < x < c:
        pdf_value = h_max
    elif c <= x <= d:
        pdf_value = ((d - x) / (d - c)) * h_max
    else:
        pdf_value = 0.0  # Shouldn't happen with the if-check above

    return np.log(pdf_value) if pdf_value > 0.0 else np.log(1e-50)


def psiam_tied_prior_fn(params):
    """
    Example of a prior where:
       (lambda, T0, theta_E) come from a correlated multivariate normal
       (t_E_aff, Z_E, L) remain from trapezoid priors (independent)
    """
    # Unpack
    rate_lambda, T_0, theta_E, t_E_aff, Z_E, L = params

    # 1) Compute logpdf of the correlated triple
    x_vec = np.array([rate_lambda, T_0, theta_E], dtype=float)
    logp_triple = logpdf_correlated_lambda_T0_thetaE(x_vec)
    if np.isinf(logp_triple):
        return -np.inf  # out of correlation domain or bounding box

    # 2) For the others, just multiply (add logs) of trapezoidal
    t_E_aff_logpdf = trapezoidal_logpdf(
        t_E_aff,
        t_E_aff_bounds[0], t_E_aff_plausible_bounds[0],
        t_E_aff_plausible_bounds[1], t_E_aff_bounds[1]
    )
    Z_E_logpdf = trapezoidal_logpdf(
        Z_E,
        Z_E_bounds[0], Z_E_plausible_bounds[0],
        Z_E_plausible_bounds[1], Z_E_bounds[1]
    )
    L_logpdf = trapezoidal_logpdf(
        L,
        L_bounds[0], L_plausible_bounds[0],
        L_plausible_bounds[1], L_bounds[1]
    )

    # If any of these are -inf, it kills the entire prior
    if np.isinf(t_E_aff_logpdf) or np.isinf(Z_E_logpdf) or np.isinf(L_logpdf):
        return -np.inf

    # 3) Total log-prior is sum of correlation triple + univariate trapezoids
    return logp_triple + t_E_aff_logpdf + Z_E_logpdf + L_logpdf

# %% [markdown]
# ## prior + loglike

# %%
def psiam_tied_joint_fn(params):
    priors = psiam_tied_prior_fn(params) 
    loglike = psiam_tied_loglike_fn(params)

    joint = priors + loglike
    return joint

# %% [markdown]
# ## run vbmc

# %%
lb = np.array([ rate_lambda_bounds[0], T_0_bounds[0], theta_E_bounds[0], \
               t_E_aff_bounds[0], Z_E_bounds[0], L_bounds[0]])
ub = np.array([ rate_lambda_bounds[1], T_0_bounds[1], theta_E_bounds[1], \
                t_E_aff_bounds[1], Z_E_bounds[1], L_bounds[1]])

plb = np.array([ rate_lambda_plausible_bounds[0], T_0_plausible_bounds[0], theta_E_plausible_bounds[0], \
                t_E_aff_plausible_bounds[0], Z_E_plausible_bounds[0], L_plausible_bounds[0]])

pub = np.array([rate_lambda_plausible_bounds[1], T_0_plausible_bounds[1], theta_E_plausible_bounds[1], \
                t_E_aff_plausible_bounds[1], Z_E_plausible_bounds[1], L_plausible_bounds[1]])


np.random.seed(42)
rate_lambda_0 = np.random.uniform(rate_lambda_plausible_bounds[0], rate_lambda_plausible_bounds[1])
T_0_0 = np.random.uniform(T_0_plausible_bounds[0], T_0_plausible_bounds[1])
theta_E_0 = np.random.uniform(theta_E_plausible_bounds[0], theta_E_plausible_bounds[1])

t_E_aff_0 = np.random.uniform(t_E_aff_plausible_bounds[0], t_E_aff_plausible_bounds[1])
Z_E_0 = np.random.uniform(Z_E_plausible_bounds[0], Z_E_plausible_bounds[1])
L_0 = np.random.uniform(L_plausible_bounds[0], L_plausible_bounds[1])

x_0 = np.array([rate_lambda_0, T_0_0, theta_E_0, t_E_aff_0, Z_E_0, L_0])

vbmc = VBMC(psiam_tied_joint_fn, x_0, lb, ub, plb, pub, options={'display': 'on'})
vp, results = vbmc.optimize()
# Out:
# Reshaping x0 to row vector.
# Reshaping lower bounds to (1, 6).
# Reshaping upper bounds to (1, 6).
# Reshaping plausible lower bounds to (1, 6).
# Reshaping plausible upper bounds to (1, 6).
# Beginning variational optimization assuming EXACT observations of the log-joint.
#  Iteration  f-count    Mean[ELBO]    Std[ELBO]    sKL-iter[q]   K[q]  Convergence  Action
#      0         10        7424.32     10192.24          inf        2        inf     start warm-up
#      1         15       15988.93      3382.30      6471.06        2        inf
#      2         20       14464.63      1861.10      1933.16        2   3.76e+04
#      3         25       13469.11       304.42       663.89        2   1.34e+04
#      4         30       13353.30       227.54       578.05        2   9.01e+03
#      5         35       15527.52      4117.42      8794.30        2   1.41e+05
#      6         40       13634.64      1131.88     25474.50        2   3.57e+05
#      7         45       14684.86      1270.71      3483.58        2   5.51e+04
#      8         50       15317.33      2133.61      2550.04        2   4.39e+04
#      9         55       14955.88      1110.29      2788.45        2   4.29e+04     trim data
#     10         60       13300.84        67.56      8458.51        2   1.21e+05
#     11         65       13234.92       103.07       915.12        2    1.3e+04
#     12         70       13218.35        90.55       270.82        2   4.04e+03
#     13         75       13369.05        86.16      1858.21        2   2.61e+04
#     14         80       13277.68        22.12      7776.52        2   1.06e+05
#     15         85       12728.02       249.28       477.31        2   9.16e+03
#     16         90       13856.29       364.20     40968.35        2   5.62e+05
#     17         95       12770.97       654.49      3585.99        2   5.46e+04
#     18        100       13379.59       146.24     27678.55        2   3.79e+05     end warm-up
#     19        105       13569.25       187.79     38730.02        2   5.28e+05
#     20        110       13587.75       122.72       289.83        2   4.41e+03
#     21        115       13412.60        56.14     17697.08        3   2.42e+05
#     22        120       13443.27       117.62       705.98        4   1.01e+04
#     23        125       13391.16        87.00      2471.20        4   3.41e+04
#     24        130       13380.83        86.67       396.60        4   5.72e+03
#     25        135       13351.26       175.20        76.20        4   1.72e+03
#     26        140       13373.87       116.33       332.38        4   4.99e+03
#     27        145       13635.29       113.44       487.55        4   7.88e+03
#     28        150       13346.32       142.62       234.40        5   4.63e+03
#     29        155       13513.41       118.54       132.56        5   2.76e+03
#     30        160       13598.47       103.45       122.55        5    2.3e+03
#     31        165       13518.92       114.00       208.31        5   3.48e+03
#     32        170       13674.69       146.38       362.51        5   5.94e+03
#     33        175       13533.82        89.60      1090.55        5   1.56e+04
#     34        180       13397.90       219.69      2159.71        5   3.06e+04
#     35        185       13344.33       211.43       141.80        5   2.81e+03
#     36        190       13396.09        62.58      3078.41        5   4.23e+04
#     37        195       13338.55        22.54       358.71        5   5.15e+03
#     38        200       13471.77        36.73       114.39        6   2.12e+03
#     39        205       13362.75        68.45       109.99        7   2.09e+03
#     40        210       13460.46        20.82        41.64        7        962
#     41        215       13397.19        30.99        14.32        8        509
#     42        220       13395.78        54.67        28.72        8        578
#     43        225       13345.55        46.46        31.81        8        755
#     44        230       13351.77        18.58       146.71        8   2.08e+03
#     45        235       13398.77        51.39       170.08        8   2.64e+03
#     46        240       13276.00        37.57        99.41        8   1.89e+03
#     47        245       13399.24        43.83       211.13        8   3.43e+03
#     48        250       13438.94        75.34       772.13        8   1.09e+04
#     49        255       13259.02       161.91       415.51        8   6.79e+03
#     50        260       13781.61       266.12      2948.04        8   4.27e+04     switch to GP opt
#     51        265       13707.44       278.89       607.66        8   9.45e+03
#     52        270       13463.27       194.48       160.02        8   3.64e+03
#     53        275       13681.00       192.48        34.66        8   1.84e+03
#     54        280       13875.69       186.20       306.75        9   5.44e+03
#     55        285       13736.56       225.79      1045.24       10   1.54e+04
#     56        290       13286.12       360.74        42.71       10   3.29e+03
#     57        295       13272.09       240.35         1.19       10        864
#     58        300       13252.06        45.70        13.88       10        408
#     59        305       13710.45       607.70       242.54       11   6.85e+03
#     60        310       17265.08       775.04      1264.73       11   3.16e+04
#     61        315       17094.35       844.12      2056.82       12   3.14e+04
#     62        320       15096.05       648.41     10132.46       12   1.47e+05
#     63        325       14692.01       301.28      1046.63       12   1.66e+04
#     64        330       14620.51       471.67       534.81       12   9.09e+03
#     65        335       14166.50      1308.65       854.34       12   1.75e+04
#     66        340       14292.26       873.42       185.09       12   5.85e+03
#     67        345       13855.17       534.91       120.68       12   4.88e+03
#     68        350       14171.75       503.61       392.91       12   8.08e+03
#     69        355       14217.09      1040.19       112.05       13   5.14e+03
#     70        360       15640.63      1120.06       841.01       13   1.99e+04
#     71        365       15118.32      1109.88      1524.18       13   2.62e+04
#     72        370       15180.68      1263.63      2887.11       13   4.37e+04
#     73        375       14502.58       454.25      1167.78       13   1.97e+04
#     74        380       16747.11      1313.09      5972.00       14   9.31e+04
#     75        385       14935.08       628.24       316.04       14   1.24e+04
#     76        390       14666.22       697.93       433.59       14   9.12e+03
#     77        395       14730.67       926.92      1265.15       14   2.05e+04
#     78        400       14186.65       440.63       558.44       14   1.09e+04
#    inf        400       17706.48       874.75     16192.80       50   3.16e+04     finalize
# Inference terminated: reached maximum number of function evaluations options.max_fun_evals.
# Estimated ELBO: 17706.481 +/-874.746.
# Caution: Returned variational solution may have not converged.

# %%
vbmc.save('NOT_working_ONLY_TIED_params_led_off_data_PRIORS_CORR.pkl')

# %%
with open('NOT_working_ONLY_TIED_params_led_off_data.pkl', 'rb') as f:
    vp = pickle.load(f)

# %%
vp = vp.vp

# %% [markdown]
# ## corner plots

# %%
vp_samples = vp.sample(int(1e5))[0]
vp_samples[:,1] = vp_samples[:,1] * 1e3

param_labels = ['lambda', 'T0', 'theta_E', 't_E', 'Z_E', 'L']

percentiles = np.percentile(vp_samples, [0, 100], axis=0)

_ranges = [(percentiles[0, i], percentiles[1, i]) for i in np.arange(vp_samples.shape[1])]


# Now create the corner plot using these ranges
corner.corner(
    vp_samples,
    labels=param_labels,
    show_titles=True,
    quantiles=[0.025, 0.5, 0.975],
    range=_ranges,
);
# Out:
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours
# Too few points to create valid contours

# %% [markdown]
# # diagnose

# %% [markdown]
# ## simulate data

# %%
lambda_mean = np.mean(vp_samples[:,0])
T0_mean = np.mean(vp_samples[:,1]) / 1e3
theta_E_mean = np.mean(vp_samples[:,2])

t_E_aff_mean = np.mean(vp_samples[:,3])
Z_E_mean = np.mean(vp_samples[:,4])
L_mean = np.mean(vp_samples[:,5])

# %%
t_stim_0 = 0.2
t_stim_tau = 0.4
iter_num = 2
N_print = 3
dt = 1e-3
N_sim = 50_000

# sample intended_fix of N_sim from df_1
t_stim_sampled = np.random.choice(df_1['intended_fix'], N_sim)

# sim_results = Parallel(n_jobs=30)(delayed(psiam_tied_data_gen_wrapper)(V_A, theta_A, ABL_arr, ILD_arr, lambda_mean, T0_mean, theta_E_mean, Z_E_mean, t_A_aff, t_E_aff_mean, t_motor, L_mean, \
#                                 t_stim_0, t_stim_tau, iter_num, N_print, dt) for iter_num in range(N_sim))
sim_results = Parallel(n_jobs=30)(delayed(psiam_tied_data_gen_wrapper_V2)(V_A, theta_A, ABL_arr, ILD_arr, lambda_mean, T0_mean, theta_E_mean, Z_E_mean, t_A_aff, t_E_aff_mean, t_motor, L_mean, \
                                                                         t_stim_sampled[iter_num], iter_num, N_print, dt) for iter_num in range(N_sim))
# Out:
# In iter_num: 0, ABL: 20, ILD: 1.0, t_stim: 0.428850070948661
# In iter_num: 3, ABL: 40, ILD: 1.0, t_stim: 0.914521084964937
# In iter_num: 6, ABL: 40, ILD: -2.0, t_stim: 1.01432688131591
# In iter_num: 9, ABL: 40, ILD: 8.0, t_stim: 0.407591617142634
# In iter_num: 12, ABL: 40, ILD: -2.0, t_stim: 0.778272653204199
# In iter_num: 15, ABL: 60, ILD: 4.0, t_stim: 0.250036934478576
# In iter_num: 18, ABL: 20, ILD: 4.0, t_stim: 0.865989876125795
# In iter_num: 21, ABL: 60, ILD: 16.0, t_stim: 0.464906246693967
# In iter_num: 24, ABL: 20, ILD: 4.0, t_stim: 0.836064660066506
# In iter_num: 27, ABL: 60, ILD: 2.0, t_stim: 0.342347444014701
# In iter_num: 30, ABL: 20, ILD: 2.0, t_stim: 0.321781191491903
# In iter_num: 33, ABL: 40, ILD: -8.0, t_stim: 0.207605170999287
# In iter_num: 36, ABL: 60, ILD: 8.0, t_stim: 0.311083950436809
# In iter_num: 39, ABL: 60, ILD: -4.0, t_stim: 0.350134096867251
# In iter_num: 42, ABL: 40, ILD: -4.0, t_stim: 0.587666454583929
# In iter_num: 45, ABL: 60, ILD: 4.0, t_stim: 0.423130259891051
# In iter_num: 48, ABL: 40, ILD: -2.0, t_stim: 0.494376815085322
# In iter_num: 51, ABL: 40, ILD: 16.0, t_stim: 0.846711789490037
# In iter_num: 54, ABL: 20, ILD: -4.0, t_stim: 1.01306131752549
# In iter_num: 57, ABL: 20, ILD: 8.0, t_stim: 0.21179398896057
# In iter_num: 60, ABL: 60, ILD: 16.0, t_stim: 0.270409696607634
# In iter_num: 66, ABL: 60, ILD: -8.0, t_stim: 0.302066466015628
# In iter_num: 72, ABL: 60, ILD: 8.0, t_stim: 1.0641325977824
# In iter_num: 63, ABL: 20, ILD: -16.0, t_stim: 0.252986580114057
# In iter_num: 78, ABL: 40, ILD: -16.0, t_stim: 0.760902255043757
# In iter_num: 69, ABL: 60, ILD: 16.0, t_stim: 0.564633767696749
# In iter_num: 84, ABL: 40, ILD: -1.0, t_stim: 0.668883999381632
# In iter_num: 81, ABL: 40, ILD: -2.0, t_stim: 0.338663947182462
# In iter_num: 90, ABL: 60, ILD: 8.0, t_stim: 0.377012052882667
# In iter_num: 75, ABL: 40, ILD: 4.0, t_stim: 0.71632370373541
# In iter_num: 96, ABL: 60, ILD: -1.0, t_stim: 2.03357230643341
# In iter_num: 87, ABL: 60, ILD: -16.0, t_stim: 0.578753036878034
# In iter_num: 93, ABL: 20, ILD: 8.0, t_stim: 0.233977237021777
# In iter_num: 102, ABL: 20, ILD: 2.0, t_stim: 0.245947885937282
# In iter_num: 99, ABL: 20, ILD: 1.0, t_stim: 0.388717379320235
# In iter_num: 108, ABL: 20, ILD: -1.0, t_stim: 0.262780073683719
# In iter_num: 105, ABL: 60, ILD: -1.0, t_stim: 0.222109389901954
# In iter_num: 114, ABL: 20, ILD: -1.0, t_stim: 0.33293923286855
# In iter_num: 120, ABL: 60, ILD: 8.0, t_stim: 0.45580472789756
# In iter_num: 126, ABL: 60, ILD: -2.0, t_stim: 0.45732898053304
# In iter_num: 132, ABL: 40, ILD: 8.0, t_stim: 0.221091217817797
# In iter_num: 138, ABL: 20, ILD: 4.0, t_stim: 0.574966331396724
# In iter_num: 111, ABL: 40, ILD: -16.0, t_stim: 0.282072914156157
# In iter_num: 129, ABL: 60, ILD: 8.0, t_stim: 0.450707699439346
# In iter_num: 123, ABL: 60, ILD: 4.0, t_stim: 0.614433616496593
# In iter_num: 141, ABL: 60, ILD: 2.0, t_stim: 0.427499516069092
# In iter_num: 144, ABL: 20, ILD: -2.0, t_stim: 0.588590202752661
# In iter_num: 135, ABL: 20, ILD: -2.0, t_stim: 1.00410777069223
# In iter_num: 150, ABL: 40, ILD: 16.0, t_stim: 0.513772688774644
# In iter_num: 147, ABL: 60, ILD: 4.0, t_stim: 0.398082995577291
# In iter_num: 117, ABL: 60, ILD: 1.0, t_stim: 0.3058707788424
# In iter_num: 156, ABL: 20, ILD: 8.0, t_stim: 0.528119544190661
# In iter_num: 153, ABL: 60, ILD: 1.0, t_stim: 0.299887843524878
# In iter_num: 162, ABL: 40, ILD: 2.0, t_stim: 0.745339841973017
# In iter_num: 165, ABL: 60, ILD: 4.0, t_stim: 0.464844775832545
# In iter_num: 159, ABL: 60, ILD: 4.0, t_stim: 0.295024412300942
# In iter_num: 168, ABL: 40, ILD: 8.0, t_stim: 1.4986199572107
# In iter_num: 174, ABL: 40, ILD: 2.0, t_stim: 0.308825760824881
# In iter_num: 171, ABL: 40, ILD: -1.0, t_stim: 0.251817932120949
# In iter_num: 180, ABL: 60, ILD: 8.0, t_stim: 0.227270302810967
# In iter_num: 177, ABL: 60, ILD: -16.0, t_stim: 0.717448478728615
# In iter_num: 192, ABL: 40, ILD: -16.0, t_stim: 0.920982722613759
# In iter_num: 186, ABL: 60, ILD: 1.0, t_stim: 0.490887909597153
# In iter_num: 204, ABL: 20, ILD: 8.0, t_stim: 0.814330161212724
# In iter_num: 216, ABL: 60, ILD: 2.0, t_stim: 0.322487629896729
# In iter_num: 189, ABL: 20, ILD: 16.0, t_stim: 0.588064287195283
# In iter_num: 201, ABL: 60, ILD: -16.0, t_stim: 0.443431274428136
# In iter_num: 213, ABL: 20, ILD: -4.0, t_stim: 0.425491528391654
# In iter_num: 210, ABL: 20, ILD: 4.0, t_stim: 0.45395208955187
# In iter_num: 228, ABL: 40, ILD: 8.0, t_stim: 0.222456030994795
# In iter_num: 240, ABL: 60, ILD: -2.0, t_stim: 1.12139442846213
# In iter_num: 195, ABL: 60, ILD: -1.0, t_stim: 1.17473699819692
# In iter_num: 252, ABL: 40, ILD: -1.0, t_stim: 0.206948898990376
# In iter_num: 222, ABL: 40, ILD: 16.0, t_stim: 1.11869629605958
# In iter_num: 198, ABL: 40, ILD: -8.0, t_stim: 0.225123496829231
# In iter_num: 219, ABL: 40, ILD: 8.0, t_stim: 0.599961186066295
# In iter_num: 261, ABL: 40, ILD: 4.0, t_stim: 0.904353697560135
# In iter_num: 225, ABL: 60, ILD: -2.0, t_stim: 1.26957534634004
# In iter_num: 237, ABL: 20, ILD: 4.0, t_stim: 0.26007039981493
# In iter_num: 249, ABL: 40, ILD: 4.0, t_stim: 0.554522331329311
# In iter_num: 264, ABL: 60, ILD: 1.0, t_stim: 0.833434384051404
# In iter_num: 276, ABL: 60, ILD: -1.0, t_stim: 0.229672636268559
# In iter_num: 288, ABL: 40, ILD: -8.0, t_stim: 0.267358967015736
# In iter_num: 183, ABL: 60, ILD: 1.0, t_stim: 0.54645102970061
# In iter_num: 300, ABL: 60, ILD: -4.0, t_stim: 0.352099465907919
# In iter_num: 312, ABL: 60, ILD: -2.0, t_stim: 0.312548377372099
# In iter_num: 258, ABL: 20, ILD: 4.0, t_stim: 0.36930525445387
# In iter_num: 255, ABL: 20, ILD: 8.0, t_stim: 0.214232392005124
# In iter_num: 273, ABL: 20, ILD: -1.0, t_stim: 0.709107026012051
# In iter_num: 324, ABL: 20, ILD: 16.0, t_stim: 0.216417551465913
# In iter_num: 297, ABL: 40, ILD: -1.0, t_stim: 0.998062517233684
# In iter_num: 231, ABL: 20, ILD: -16.0, t_stim: 0.534172297671327
# In iter_num: 234, ABL: 60, ILD: -4.0, t_stim: 0.628366915827519
# In iter_num: 309, ABL: 20, ILD: -16.0, t_stim: 0.255984371276875
# In iter_num: 285, ABL: 20, ILD: 8.0, t_stim: 0.923024099505762
# In iter_num: 321, ABL: 40, ILD: -4.0, t_stim: 0.495579973566581
# In iter_num: 336, ABL: 20, ILD: 2.0, t_stim: 0.237400267552603
# In iter_num: 246, ABL: 60, ILD: 1.0, t_stim: 0.594050059303392
# In iter_num: 294, ABL: 60, ILD: 8.0, t_stim: 0.636102845646855
# In iter_num: 207, ABL: 20, ILD: 8.0, t_stim: 0.222071398026003
# In iter_num: 282, ABL: 40, ILD: -1.0, t_stim: 0.239381022422345
# In iter_num: 306, ABL: 40, ILD: 4.0, t_stim: 0.301250310557484In iter_num: 267, ABL: 60, ILD: -8.0, t_stim: 0.88751660901197
#
# In iter_num: 270, ABL: 40, ILD: 4.0, t_stim: 0.306186372802406
# In iter_num: 330, ABL: 20, ILD: 2.0, t_stim: 0.943936147114066
# In iter_num: 318, ABL: 20, ILD: -16.0, t_stim: 0.318513469340742
# In iter_num: 243, ABL: 20, ILD: -16.0, t_stim: 0.269071007459251
# In iter_num: 315, ABL: 20, ILD: 2.0, t_stim: 0.507345338793019
# In iter_num: 303, ABL: 40, ILD: 1.0, t_stim: 0.451114532898093
# In iter_num: 348, ABL: 60, ILD: 4.0, t_stim: 0.475027230222895
# In iter_num: 333, ABL: 20, ILD: -16.0, t_stim: 0.201901698110605
# In iter_num: 360, ABL: 40, ILD: 8.0, t_stim: 0.205208126757343
# In iter_num: 279, ABL: 60, ILD: -4.0, t_stim: 0.506282374488457
# In iter_num: 291, ABL: 60, ILD: -2.0, t_stim: 0.255765138654678
# In iter_num: 372, ABL: 20, ILD: 2.0, t_stim: 0.319685250478034
# In iter_num: 357, ABL: 60, ILD: -2.0, t_stim: 0.804780319144922
# In iter_num: 384, ABL: 40, ILD: -16.0, t_stim: 0.206468853831297
# In iter_num: 327, ABL: 40, ILD: 16.0, t_stim: 1.08356452611008
# In iter_num: 369, ABL: 20, ILD: 8.0, t_stim: 0.468046189447818
# In iter_num: 396, ABL: 60, ILD: -16.0, t_stim: 1.40588433339463
# In iter_num: 408, ABL: 20, ILD: 2.0, t_stim: 0.783761567406032
# In iter_num: 345, ABL: 40, ILD: 1.0, t_stim: 0.270685498007907
# In iter_num: 420, ABL: 60, ILD: -2.0, t_stim: 0.259641110740759
# In iter_num: 393, ABL: 20, ILD: 2.0, t_stim: 0.864948936164541
# In iter_num: 444, ABL: 60, ILD: 2.0, t_stim: 0.235895689837453
# In iter_num: 381, ABL: 20, ILD: 1.0, t_stim: 0.546730745477507
# In iter_num: 354, ABL: 60, ILD: 2.0, t_stim: 0.311984993313931
# In iter_num: 417, ABL: 20, ILD: 8.0, t_stim: 0.865218873515558
# In iter_num: 468, ABL: 40, ILD: 2.0, t_stim: 0.560209618835963
# In iter_num: 342, ABL: 60, ILD: -1.0, t_stim: 1.28092135831156
# In iter_num: 378, ABL: 60, ILD: 8.0, t_stim: 0.332071717398077
# In iter_num: 405, ABL: 60, ILD: -4.0, t_stim: 1.09884310006483
# In iter_num: 351, ABL: 40, ILD: 1.0, t_stim: 0.261823071919592
# In iter_num: 366, ABL: 20, ILD: -2.0, t_stim: 0.403342442744033
# In iter_num: 402, ABL: 40, ILD: -1.0, t_stim: 0.481552190192551
# In iter_num: 429, ABL: 20, ILD: -2.0, t_stim: 0.558914616632469
# In iter_num: 387, ABL: 60, ILD: -1.0, t_stim: 0.784854916622423
# In iter_num: 339, ABL: 60, ILD: -4.0, t_stim: 0.234122281049451
# In iter_num: 438, ABL: 40, ILD: 8.0, t_stim: 0.293581995929312
# In iter_num: 453, ABL: 20, ILD: 1.0, t_stim: 0.656157155977461
# In iter_num: 414, ABL: 60, ILD: -4.0, t_stim: 0.270064306850825
# In iter_num: 492, ABL: 40, ILD: -8.0, t_stim: 0.703467745389321
# In iter_num: 390, ABL: 40, ILD: 8.0, t_stim: 0.412658443592939
# In iter_num: 477, ABL: 40, ILD: 1.0, t_stim: 0.607442917793584
# In iter_num: 399, ABL: 60, ILD: -1.0, t_stim: 0.216288415667578
# In iter_num: 462, ABL: 20, ILD: 16.0, t_stim: 0.973594747291259
# In iter_num: 363, ABL: 40, ILD: 8.0, t_stim: 0.219936219743095
# In iter_num: 516, ABL: 40, ILD: 2.0, t_stim: 0.448779183410314
# In iter_num: 447, ABL: 20, ILD: 8.0, t_stim: 0.649569084192549
# In iter_num: 540, ABL: 20, ILD: -16.0, t_stim: 0.570553336768036
# In iter_num: 375, ABL: 20, ILD: 1.0, t_stim: 0.698960533350662
# In iter_num: 525, ABL: 20, ILD: 4.0, t_stim: 0.219023326784435
# In iter_num: 501, ABL: 20, ILD: 8.0, t_stim: 0.704606933936991
# In iter_num: 471, ABL: 40, ILD: -16.0, t_stim: 0.302855535244009
# In iter_num: 411, ABL: 20, ILD: -16.0, t_stim: 0.340713398376845
# In iter_num: 510, ABL: 60, ILD: -1.0, t_stim: 0.246809637701385
# In iter_num: 564, ABL: 40, ILD: -2.0, t_stim: 0.281502263639316
# In iter_num: 588, ABL: 40, ILD: 8.0, t_stim: 1.19503230654008
# In iter_num: 612, ABL: 60, ILD: 2.0, t_stim: 0.709372325185685
# In iter_num: 441, ABL: 20, ILD: -16.0, t_stim: 0.363696917815967
# In iter_num: 573, ABL: 60, ILD: -4.0, t_stim: 0.252958225760135
# In iter_num: 423, ABL: 20, ILD: -4.0, t_stim: 0.208934461102279
# In iter_num: 495, ABL: 20, ILD: 2.0, t_stim: 1.15407213816687
# In iter_num: 549, ABL: 20, ILD: 8.0, t_stim: 0.286421021162951
# In iter_num: 534, ABL: 60, ILD: -4.0, t_stim: 0.211881837027973
# In iter_num: 558, ABL: 20, ILD: 8.0, t_stim: 0.30980778324521
# In iter_num: 597, ABL: 20, ILD: -8.0, t_stim: 0.287567776043544
# In iter_num: 519, ABL: 60, ILD: -16.0, t_stim: 0.226075664881512
# In iter_num: 486, ABL: 40, ILD: -8.0, t_stim: 0.296229804409005
# In iter_num: 432, ABL: 60, ILD: 4.0, t_stim: 0.457339010805728
# In iter_num: 456, ABL: 60, ILD: -1.0, t_stim: 0.61342424616417
# In iter_num: 480, ABL: 20, ILD: 1.0, t_stim: 0.608816387685791
# In iter_num: 606, ABL: 20, ILD: -1.0, t_stim: 0.875719104915022
# In iter_num: 450, ABL: 20, ILD: 4.0, t_stim: 0.283858574969038
# In iter_num: 621, ABL: 60, ILD: 4.0, t_stim: 0.216032370109101
# In iter_num: 582, ABL: 40, ILD: 4.0, t_stim: 0.765818257654378
# In iter_num: 636, ABL: 40, ILD: 1.0, t_stim: 0.544888291090213
# In iter_num: 504, ABL: 20, ILD: 8.0, t_stim: 0.533537711804773
# In iter_num: 567, ABL: 60, ILD: 4.0, t_stim: 0.569424083018622
# In iter_num: 543, ABL: 40, ILD: 2.0, t_stim: 0.548504109389624
# In iter_num: 513, ABL: 20, ILD: -16.0, t_stim: 0.232492244685628
# In iter_num: 528, ABL: 40, ILD: 8.0, t_stim: 1.34810825483112
# In iter_num: 465, ABL: 40, ILD: -2.0, t_stim: 0.904642591775664
# In iter_num: 474, ABL: 40, ILD: 8.0, t_stim: 0.305376176699528
# In iter_num: 552, ABL: 40, ILD: -16.0, t_stim: 0.411336718172679
# In iter_num: 591, ABL: 60, ILD: 8.0, t_stim: 0.645784844590662
# In iter_num: 600, ABL: 20, ILD: -16.0, t_stim: 0.513397623228068
# In iter_num: 498, ABL: 60, ILD: 8.0, t_stim: 0.350850945362554
# In iter_num: 522, ABL: 60, ILD: 16.0, t_stim: 0.814776258723867
# In iter_num: 660, ABL: 20, ILD: 2.0, t_stim: 0.295683169172213
# In iter_num: 576, ABL: 20, ILD: 1.0, t_stim: 0.246480118981576
# In iter_num: 561, ABL: 20, ILD: 16.0, t_stim: 0.691312672214345
# In iter_num: 684, ABL: 60, ILD: 8.0, t_stim: 0.271497211709608
# In iter_num: 426, ABL: 60, ILD: -1.0, t_stim: 0.330349540432393
# In iter_num: 603, ABL: 40, ILD: -2.0, t_stim: 0.227737508084854
# In iter_num: 630, ABL: 40, ILD: -4.0, t_stim: 0.222072442914009
# In iter_num: 654, ABL: 40, ILD: -1.0, t_stim: 0.395292237687741
# In iter_num: 555, ABL: 20, ILD: 8.0, t_stim: 0.243102387588181
# In iter_num: 489, ABL: 20, ILD: -2.0, t_stim: 0.76280730770622
# In iter_num: 669, ABL: 20, ILD: 2.0, t_stim: 0.473550891099999
# In iter_num: 708, ABL: 40, ILD: -2.0, t_stim: 0.38725803526062
# In iter_num: 459, ABL: 20, ILD: 16.0, t_stim: 0.368958646029988In iter_num: 570, ABL: 20, ILD: -8.0, t_stim: 0.417615754702399
#
# In iter_num: 639, ABL: 60, ILD: 1.0, t_stim: 0.36587574946174
# In iter_num: 615, ABL: 40, ILD: -8.0, t_stim: 0.346890493779935
# In iter_num: 693, ABL: 40, ILD: -2.0, t_stim: 0.323109002309093
# In iter_num: 531, ABL: 40, ILD: -2.0, t_stim: 0.406363412358353
# In iter_num: 507, ABL: 60, ILD: -8.0, t_stim: 0.919122668583394
# In iter_num: 609, ABL: 40, ILD: 16.0, t_stim: 1.17993486236953
# In iter_num: 657, ABL: 60, ILD: 2.0, t_stim: 0.551346163938893
# In iter_num: 624, ABL: 60, ILD: 8.0, t_stim: 1.14236673229207
# In iter_num: 717, ABL: 40, ILD: 1.0, t_stim: 0.47307941172469
# In iter_num: 435, ABL: 40, ILD: -2.0, t_stim: 0.229022522447096
# In iter_num: 483, ABL: 60, ILD: 16.0, t_stim: 0.306514839331751
# In iter_num: 732, ABL: 40, ILD: 4.0, t_stim: 0.816596003842709
# In iter_num: 678, ABL: 20, ILD: 1.0, t_stim: 0.67957413048799
# In iter_num: 696, ABL: 40, ILD: -2.0, t_stim: 0.458421196252017
# In iter_num: 594, ABL: 20, ILD: 8.0, t_stim: 0.362954582759937
# In iter_num: 663, ABL: 60, ILD: -4.0, t_stim: 0.274407508054824
# In iter_num: 687, ABL: 60, ILD: 4.0, t_stim: 0.346297379334999
# In iter_num: 756, ABL: 60, ILD: -8.0, t_stim: 0.380983866292336
# In iter_num: 702, ABL: 60, ILD: 16.0, t_stim: 0.716786619088316
# In iter_num: 645, ABL: 60, ILD: 1.0, t_stim: 0.228599129834792
# In iter_num: 699, ABL: 20, ILD: -4.0, t_stim: 0.590687247040371
# In iter_num: 741, ABL: 60, ILD: 4.0, t_stim: 1.02535087905894
# In iter_num: 780, ABL: 20, ILD: 16.0, t_stim: 0.471094870340181
# In iter_num: 765, ABL: 20, ILD: -8.0, t_stim: 0.433479476330656
# In iter_num: 750, ABL: 60, ILD: 1.0, t_stim: 0.628248776633504
# In iter_num: 633, ABL: 20, ILD: 1.0, t_stim: 0.384407318348922
# In iter_num: 585, ABL: 20, ILD: -16.0, t_stim: 0.263538522599784
# In iter_num: 720, ABL: 20, ILD: 4.0, t_stim: 0.541956902195689
# In iter_num: 804, ABL: 40, ILD: 4.0, t_stim: 0.213693843285737
# In iter_num: 579, ABL: 60, ILD: -4.0, t_stim: 0.545732980050184
# In iter_num: 681, ABL: 60, ILD: 4.0, t_stim: 0.304272110395165
# In iter_num: 666, ABL: 20, ILD: 4.0, t_stim: 0.332011297341877
# In iter_num: 546, ABL: 60, ILD: 2.0, t_stim: 0.209479873394935
# In iter_num: 711, ABL: 20, ILD: 2.0, t_stim: 0.217102515564599
# In iter_num: 642, ABL: 20, ILD: 16.0, t_stim: 0.211623773367851
# In iter_num: 789, ABL: 60, ILD: -8.0, t_stim: 0.397212929942609
# In iter_num: 537, ABL: 40, ILD: -8.0, t_stim: 0.338009443420662
# In iter_num: 627, ABL: 20, ILD: 2.0, t_stim: 0.284154189639776
# In iter_num: 798, ABL: 20, ILD: -1.0, t_stim: 0.86055076885727
# In iter_num: 618, ABL: 20, ILD: -4.0, t_stim: 0.723008852760087
# In iter_num: 726, ABL: 40, ILD: -2.0, t_stim: 0.716636070963211
# In iter_num: 759, ABL: 20, ILD: -1.0, t_stim: 1.80301512755273
# In iter_num: 723, ABL: 40, ILD: -8.0, t_stim: 0.334776973991117
# In iter_num: 705, ABL: 20, ILD: 16.0, t_stim: 0.911058223394707
# In iter_num: 774, ABL: 20, ILD: -1.0, t_stim: 0.584856693639231
# In iter_num: 828, ABL: 20, ILD: -1.0, t_stim: 0.852451882336677
# In iter_num: 792, ABL: 40, ILD: 16.0, t_stim: 0.747818401072196
# In iter_num: 813, ABL: 60, ILD: -4.0, t_stim: 1.24336574915546
# In iter_num: 690, ABL: 40, ILD: -16.0, t_stim: 0.405002949469145
# In iter_num: 852, ABL: 40, ILD: 16.0, t_stim: 0.461179578849113
# In iter_num: 648, ABL: 40, ILD: 4.0, t_stim: 0.57273298031934
# In iter_num: 837, ABL: 40, ILD: 8.0, t_stim: 0.272909386940223
# In iter_num: 753, ABL: 60, ILD: 2.0, t_stim: 0.335423002702522
# In iter_num: 807, ABL: 40, ILD: -4.0, t_stim: 0.48202902724389
# In iter_num: 729, ABL: 20, ILD: -2.0, t_stim: 0.276242103128648
# In iter_num: 876, ABL: 60, ILD: -8.0, t_stim: 0.481433069650582
# In iter_num: 783, ABL: 60, ILD: -2.0, t_stim: 0.348465767455412
# In iter_num: 801, ABL: 60, ILD: -16.0, t_stim: 0.313418385172343
# In iter_num: 735, ABL: 20, ILD: 8.0, t_stim: 0.274154522439351
# In iter_num: 795, ABL: 60, ILD: -1.0, t_stim: 0.267436020459423
# In iter_num: 840, ABL: 20, ILD: -4.0, t_stim: 0.273914662146926
# In iter_num: 846, ABL: 60, ILD: 4.0, t_stim: 0.286676637771687
# In iter_num: 672, ABL: 40, ILD: -16.0, t_stim: 0.44631503423567
# In iter_num: 861, ABL: 60, ILD: 1.0, t_stim: 0.235367217271542
# In iter_num: 768, ABL: 20, ILD: -16.0, t_stim: 0.248652534685479
# In iter_num: 822, ABL: 20, ILD: 4.0, t_stim: 0.455684252031786
# In iter_num: 885, ABL: 60, ILD: -2.0, t_stim: 0.512341439489216
# In iter_num: 900, ABL: 40, ILD: 2.0, t_stim: 0.397923267460974
# In iter_num: 714, ABL: 20, ILD: 8.0, t_stim: 0.326910415533854
# In iter_num: 744, ABL: 60, ILD: -1.0, t_stim: 0.303517833468627
# In iter_num: 948, ABL: 40, ILD: -8.0, t_stim: 0.622281326619985
# In iter_num: 762, ABL: 20, ILD: -16.0, t_stim: 0.903087581520446
# In iter_num: 843, ABL: 60, ILD: -8.0, t_stim: 0.394142933023043
# In iter_num: 903, ABL: 60, ILD: -8.0, t_stim: 0.455144461984364
# In iter_num: 831, ABL: 20, ILD: 8.0, t_stim: 0.467106299936131
# In iter_num: 894, ABL: 40, ILD: -4.0, t_stim: 1.34912558923297
# In iter_num: 933, ABL: 20, ILD: -8.0, t_stim: 0.262198115610536
# In iter_num: 996, ABL: 20, ILD: -16.0, t_stim: 0.460456376506414
# In iter_num: 981, ABL: 20, ILD: 1.0, t_stim: 0.246641387058285
# In iter_num: 870, ABL: 20, ILD: 2.0, t_stim: 0.29467100232088
# In iter_num: 651, ABL: 40, ILD: -2.0, t_stim: 0.266514897375306
# In iter_num: 918, ABL: 20, ILD: -2.0, t_stim: 0.74582328147354
# In iter_num: 738, ABL: 40, ILD: 2.0, t_stim: 0.302579737739508
# In iter_num: 816, ABL: 40, ILD: 8.0, t_stim: 0.212863619241767In iter_num: 855, ABL: 60, ILD: 4.0, t_stim: 0.24729798071892
#
# In iter_num: 810, ABL: 20, ILD: -8.0, t_stim: 0.837483524810962
# In iter_num: 849, ABL: 60, ILD: -16.0, t_stim: 0.338005718735101
# In iter_num: 966, ABL: 60, ILD: 8.0, t_stim: 0.393300901674157
# In iter_num: 777, ABL: 40, ILD: -4.0, t_stim: 0.416209857720845
# In iter_num: 1044, ABL: 60, ILD: -4.0, t_stim: 0.754879142034849
# In iter_num: 888, ABL: 60, ILD: -1.0, t_stim: 0.341599452932311
# In iter_num: 906, ABL: 20, ILD: 8.0, t_stim: 0.396541378811709
# In iter_num: 999, ABL: 40, ILD: 2.0, t_stim: 0.231135606938949
# In iter_num: 786, ABL: 40, ILD: -1.0, t_stim: 0.485644774074792
# In iter_num: 825, ABL: 40, ILD: -16.0, t_stim: 0.410690856828254
# In iter_num: 879, ABL: 60, ILD: -1.0, t_stim: 0.362660628128449
# In iter_num: 864, ABL: 60, ILD: -8.0, t_stim: 0.306725582607376
# In iter_num: 1029, ABL: 20, ILD: -2.0, t_stim: 0.316896502097245
# In iter_num: 936, ABL: 20, ILD: 16.0, t_stim: 0.289838068441555
# In iter_num: 1092, ABL: 60, ILD: -2.0, t_stim: 0.24203844262164
# In iter_num: 675, ABL: 20, ILD: 16.0, t_stim: 0.743444852738334
# In iter_num: 771, ABL: 60, ILD: 16.0, t_stim: 0.3332290159458
# In iter_num: 921, ABL: 60, ILD: -4.0, t_stim: 0.241897757191605
# In iter_num: 897, ABL: 60, ILD: -1.0, t_stim: 0.426630372415431
# In iter_num: 951, ABL: 60, ILD: 16.0, t_stim: 0.31978833168456
# In iter_num: 1002, ABL: 40, ILD: 8.0, t_stim: 0.681194892927676
# In iter_num: 891, ABL: 40, ILD: 2.0, t_stim: 0.390697947720503
# In iter_num: 1077, ABL: 60, ILD: 4.0, t_stim: 1.85827461028389
# In iter_num: 909, ABL: 20, ILD: 1.0, t_stim: 0.415554352715746
# In iter_num: 873, ABL: 60, ILD: 1.0, t_stim: 0.392655318320276
# In iter_num: 834, ABL: 60, ILD: 4.0, t_stim: 0.222518221347674
# In iter_num: 747, ABL: 40, ILD: -8.0, t_stim: 0.5175029733729
# In iter_num: 1014, ABL: 40, ILD: -1.0, t_stim: 0.295488300931728
# In iter_num: 1140, ABL: 60, ILD: -16.0, t_stim: 0.540236408607024
# In iter_num: 969, ABL: 20, ILD: 16.0, t_stim: 0.397680731074831
# In iter_num: 1062, ABL: 40, ILD: -1.0, t_stim: 1.20779237752034
# In iter_num: 858, ABL: 40, ILD: 1.0, t_stim: 0.364091999365628
# In iter_num: 939, ABL: 60, ILD: -4.0, t_stim: 0.299630923630618
# In iter_num: 819, ABL: 40, ILD: 8.0, t_stim: 0.394746252254951
# In iter_num: 1188, ABL: 40, ILD: -16.0, t_stim: 0.385591936081994
# In iter_num: 1173, ABL: 40, ILD: -1.0, t_stim: 0.675602920894728
# In iter_num: 1125, ABL: 40, ILD: 2.0, t_stim: 0.868819166393298
# In iter_num: 1005, ABL: 40, ILD: 2.0, t_stim: 0.267436020459423
# In iter_num: 1017, ABL: 20, ILD: 2.0, t_stim: 0.553364071511166
# In iter_num: 882, ABL: 60, ILD: -2.0, t_stim: 0.275860896166931
# In iter_num: 867, ABL: 60, ILD: -8.0, t_stim: 0.40249178115688
# In iter_num: 1047, ABL: 60, ILD: -1.0, t_stim: 1.01408617428659
# In iter_num: 1236, ABL: 20, ILD: 8.0, t_stim: 0.444930285351463
# In iter_num: 1110, ABL: 60, ILD: -16.0, t_stim: 0.326425054948045
# In iter_num: 912, ABL: 40, ILD: -2.0, t_stim: 0.337038485672665
# In iter_num: 924, ABL: 60, ILD: 4.0, t_stim: 0.334712573843765
# In iter_num: 1284, ABL: 40, ILD: 4.0, t_stim: 0.379666203710145
# In iter_num: 972, ABL: 40, ILD: -2.0, t_stim: 0.492434328027289
# In iter_num: 1206, ABL: 40, ILD: -8.0, t_stim: 0.471928734832533
# In iter_num: 1008, ABL: 40, ILD: -8.0, t_stim: 0.576239345611806
# In iter_num: 1221, ABL: 20, ILD: -16.0, t_stim: 0.493419562763363
# In iter_num: 954, ABL: 40, ILD: 8.0, t_stim: 0.203017925670561
# In iter_num: 1158, ABL: 20, ILD: 8.0, t_stim: 0.286622095672955
# In iter_num: 1143, ABL: 40, ILD: 16.0, t_stim: 0.229756059601486
# In iter_num: 1332, ABL: 40, ILD: -4.0, t_stim: 0.95336623260488
# In iter_num: 942, ABL: 20, ILD: 8.0, t_stim: 0.249936655537409
# In iter_num: 915, ABL: 40, ILD: 4.0, t_stim: 0.211569995880168
# In iter_num: 984, ABL: 40, ILD: -8.0, t_stim: 0.240551265152952
# In iter_num: 1269, ABL: 60, ILD: 2.0, t_stim: 0.533089361056437
# In iter_num: 1032, ABL: 60, ILD: -8.0, t_stim: 0.298646834145799
# In iter_num: 1020, ABL: 60, ILD: -4.0, t_stim: 0.847314851570763
# In iter_num: 1080, ABL: 20, ILD: 2.0, t_stim: 0.480865129480186
# In iter_num: 1380, ABL: 60, ILD: 16.0, t_stim: 0.379666203710145
# In iter_num: 1128, ABL: 60, ILD: 1.0, t_stim: 0.222029516906546
# In iter_num: 1317, ABL: 60, ILD: -1.0, t_stim: 0.404585058493444
# In iter_num: 1254, ABL: 40, ILD: 4.0, t_stim: 1.10550525522517
# In iter_num: 1050, ABL: 40, ILD: 8.0, t_stim: 0.588732671226254
# In iter_num: 1365, ABL: 20, ILD: -16.0, t_stim: 0.293957956994809
# In iter_num: 1011, ABL: 60, ILD: -4.0, t_stim: 0.60433696520187
# In iter_num: 1065, ABL: 60, ILD: -4.0, t_stim: 0.219591486057894
# In iter_num: 1095, ABL: 40, ILD: -1.0, t_stim: 0.202355101300737
# In iter_num: 1176, ABL: 40, ILD: -16.0, t_stim: 0.631050857080992
# In iter_num: 1302, ABL: 40, ILD: 2.0, t_stim: 0.430974059322914
# In iter_num: 1191, ABL: 40, ILD: -1.0, t_stim: 0.669624514074231
# In iter_num: 1146, ABL: 40, ILD: 1.0, t_stim: 0.441601726533313
# In iter_num: 927, ABL: 40, ILD: 1.0, t_stim: 0.554027624970383
# In iter_num: 1023, ABL: 40, ILD: 2.0, t_stim: 0.309672032671438
# In iter_num: 1209, ABL: 20, ILD: 1.0, t_stim: 0.614810306908684
# In iter_num: 1113, ABL: 20, ILD: 1.0, t_stim: 0.418293622767077
# In iter_num: 945, ABL: 40, ILD: 4.0, t_stim: 0.69556579296818
# In iter_num: 1368, ABL: 60, ILD: -1.0, t_stim: 0.803865326730755
# In iter_num: 1161, ABL: 20, ILD: 16.0, t_stim: 0.437401139548148
# In iter_num: 1053, ABL: 20, ILD: 1.0, t_stim: 0.248383147523062
# In iter_num: 1131, ABL: 20, ILD: -8.0, t_stim: 0.550101939565688
# In iter_num: 1383, ABL: 40, ILD: -1.0, t_stim: 0.264889981276404
# In iter_num: 957, ABL: 60, ILD: 16.0, t_stim: 0.809076689360255
# In iter_num: 975, ABL: 40, ILD: 1.0, t_stim: 0.990472632328132
# In iter_num: 1350, ABL: 40, ILD: 2.0, t_stim: 0.285719121360695
# In iter_num: 1335, ABL: 20, ILD: -8.0, t_stim: 0.735560210501796
# In iter_num: 1026, ABL: 60, ILD: -4.0, t_stim: 0.719626493794583
# In iter_num: 1398, ABL: 60, ILD: -4.0, t_stim: 0.5225816117806
# In iter_num: 1287, ABL: 60, ILD: 1.0, t_stim: 0.832350801934689
# In iter_num: 1371, ABL: 40, ILD: -16.0, t_stim: 0.724500227777883
# In iter_num: 1068, ABL: 20, ILD: -8.0, t_stim: 0.342347444014701
# In iter_num: 1272, ABL: 60, ILD: -8.0, t_stim: 0.339727895983769
# In iter_num: 1083, ABL: 20, ILD: -1.0, t_stim: 0.77782319838915
# In iter_num: 1320, ABL: 20, ILD: -2.0, t_stim: 0.810897690380237
# In iter_num: 1035, ABL: 60, ILD: 8.0, t_stim: 0.327911891498503
# In iter_num: 1179, ABL: 40, ILD: 16.0, t_stim: 0.617202293460615
# In iter_num: 1224, ABL: 40, ILD: 8.0, t_stim: 0.211780925402285
# In iter_num: 1257, ABL: 60, ILD: -1.0, t_stim: 0.51950369764767
# In iter_num: 1401, ABL: 20, ILD: -16.0, t_stim: 0.829398238852444
# In iter_num: 1239, ABL: 60, ILD: -2.0, t_stim: 0.335079060666037
# In iter_num: 1134, ABL: 40, ILD: -8.0, t_stim: 0.208473324218974
# In iter_num: 930, ABL: 60, ILD: -4.0, t_stim: 0.450655060244957
# In iter_num: 1056, ABL: 20, ILD: -4.0, t_stim: 0.203431111435786
# In iter_num: 1212, ABL: 60, ILD: -4.0, t_stim: 0.600529692384484
# In iter_num: 1374, ABL: 40, ILD: -16.0, t_stim: 0.371136703370633
# In iter_num: 1305, ABL: 60, ILD: 4.0, t_stim: 0.822023495058299
# In iter_num: 978, ABL: 60, ILD: -2.0, t_stim: 0.386789061429411
# In iter_num: 1116, ABL: 60, ILD: 8.0, t_stim: 0.260147001014244
# In iter_num: 1149, ABL: 20, ILD: -4.0, t_stim: 0.44631503423567
# In iter_num: 1338, ABL: 60, ILD: 16.0, t_stim: 0.722793346040717
# In iter_num: 1404, ABL: 40, ILD: -8.0, t_stim: 0.234396566512868
# In iter_num: 987, ABL: 20, ILD: 1.0, t_stim: 0.445765245600415
# In iter_num: 1428, ABL: 60, ILD: 1.0, t_stim: 0.461690419909331
# In iter_num: 1353, ABL: 20, ILD: -2.0, t_stim: 0.465719473229914
# In iter_num: 1386, ABL: 60, ILD: -2.0, t_stim: 0.242779839051256
# In iter_num: 1164, ABL: 40, ILD: -2.0, t_stim: 0.489081435520044
# In iter_num: 1413, ABL: 20, ILD: 1.0, t_stim: 0.483978239036119
# In iter_num: 1275, ABL: 40, ILD: -16.0, t_stim: 0.627038649411456
# In iter_num: 960, ABL: 40, ILD: 2.0, t_stim: 0.681256166626373
# In iter_num: 1194, ABL: 20, ILD: -1.0, t_stim: 0.397282223385491
# In iter_num: 1290, ABL: 60, ILD: -4.0, t_stim: 0.996164015173343
# In iter_num: 1377, ABL: 20, ILD: 2.0, t_stim: 0.42744568307539
# In iter_num: 1059, ABL: 20, ILD: -8.0, t_stim: 0.524127652270664
# In iter_num: 1242, ABL: 40, ILD: -4.0, t_stim: 0.289025296611719
# In iter_num: 1260, ABL: 40, ILD: -8.0, t_stim: 0.204977251164809In iter_num: 1323, ABL: 40, ILD: 1.0, t_stim: 0.383126774874627
#
# In iter_num: 1407, ABL: 60, ILD: 2.0, t_stim: 0.203301275788043
# In iter_num: 1086, ABL: 20, ILD: 16.0, t_stim: 0.225941640252147
# In iter_num: 1071, ABL: 60, ILD: -8.0, t_stim: 0.915126097681348
# In iter_num: 1215, ABL: 20, ILD: -1.0, t_stim: 0.442428590461171
# In iter_num: 1152, ABL: 40, ILD: -1.0, t_stim: 0.241740378108953
# In iter_num: 1038, ABL: 40, ILD: 1.0, t_stim: 0.302892494237209
# In iter_num: 1416, ABL: 20, ILD: 16.0, t_stim: 0.322441781617074
# In iter_num: 1431, ABL: 20, ILD: -8.0, t_stim: 1.23805849732068
# In iter_num: 1137, ABL: 20, ILD: 16.0, t_stim: 1.22832209034761
# In iter_num: 1476, ABL: 60, ILD: -4.0, t_stim: 1.05034557310472
# In iter_num: 1227, ABL: 60, ILD: 8.0, t_stim: 0.20172062559006
# In iter_num: 1446, ABL: 20, ILD: 2.0, t_stim: 0.467641000626803
# In iter_num: 1410, ABL: 40, ILD: -16.0, t_stim: 0.381349076272632
# In iter_num: 1461, ABL: 20, ILD: 4.0, t_stim: 0.400393021396822
# In iter_num: 1278, ABL: 40, ILD: 16.0, t_stim: 0.280465563474997
# In iter_num: 1119, ABL: 20, ILD: -1.0, t_stim: 0.392692924899217
# In iter_num: 1182, ABL: 20, ILD: -2.0, t_stim: 0.671352886373098
# In iter_num: 1356, ABL: 60, ILD: -1.0, t_stim: 0.880513865829374
# In iter_num: 1341, ABL: 40, ILD: -4.0, t_stim: 0.511542336239924
# In iter_num: 1098, ABL: 60, ILD: 8.0, t_stim: 0.897509402097085
# In iter_num: 963, ABL: 20, ILD: 1.0, t_stim: 0.259429208687086
# In iter_num: 1167, ABL: 60, ILD: -16.0, t_stim: 0.824448039199283
# In iter_num: 1089, ABL: 20, ILD: 2.0, t_stim: 0.283268468282161
# In iter_num: 1308, ABL: 40, ILD: -2.0, t_stim: 0.672564376911736
# In iter_num: 1419, ABL: 60, ILD: 16.0, t_stim: 0.225231048844786
# In iter_num: 1155, ABL: 20, ILD: -2.0, t_stim: 0.265148698394778
# In iter_num: 1509, ABL: 40, ILD: -4.0, t_stim: 1.06573112525091
# In iter_num: 1293, ABL: 60, ILD: -1.0, t_stim: 0.813838106686641
# In iter_num: 1479, ABL: 60, ILD: -1.0, t_stim: 1.18061539705992
# In iter_num: 1197, ABL: 20, ILD: 16.0, t_stim: 0.280388600638851
# In iter_num: 1494, ABL: 20, ILD: -8.0, t_stim: 0.458421049521999
# In iter_num: 1245, ABL: 60, ILD: 16.0, t_stim: 0.27328770417591
# In iter_num: 1422, ABL: 60, ILD: 8.0, t_stim: 0.492557546621284
# In iter_num: 1326, ABL: 60, ILD: 4.0, t_stim: 0.274366380778503
# In iter_num: 1524, ABL: 40, ILD: -16.0, t_stim: 0.306828686080082
# In iter_num: 1389, ABL: 60, ILD: 1.0, t_stim: 0.450810764622624
# In iter_num: 1230, ABL: 60, ILD: 16.0, t_stim: 1.04143739919006
# In iter_num: 1218, ABL: 40, ILD: -4.0, t_stim: 0.410477943794222
# In iter_num: 1263, ABL: 40, ILD: 1.0, t_stim: 0.311157146531455
# In iter_num: 1434, ABL: 40, ILD: -1.0, t_stim: 0.257155187782682
# In iter_num: 1512, ABL: 20, ILD: 1.0, t_stim: 0.770749340695324
# In iter_num: 1041, ABL: 40, ILD: 1.0, t_stim: 0.403263011531701
# In iter_num: 1449, ABL: 40, ILD: -2.0, t_stim: 0.74018828596781
# In iter_num: 1482, ABL: 60, ILD: -16.0, t_stim: 1.01026844558965
# In iter_num: 1122, ABL: 20, ILD: 16.0, t_stim: 2.00913486756648
# In iter_num: 1074, ABL: 20, ILD: 16.0, t_stim: 0.203974271378512
# In iter_num: 1497, ABL: 60, ILD: 16.0, t_stim: 1.19063349656512
# In iter_num: 1557, ABL: 40, ILD: -16.0, t_stim: 0.41090938612886
# In iter_num: 1344, ABL: 40, ILD: 2.0, t_stim: 0.208911594056505
# In iter_num: 1281, ABL: 60, ILD: -1.0, t_stim: 0.507091034060967
# In iter_num: 1515, ABL: 40, ILD: 2.0, t_stim: 0.432701711926556
# In iter_num: 1425, ABL: 40, ILD: 16.0, t_stim: 0.843221658594904
# In iter_num: 1485, ABL: 20, ILD: -16.0, t_stim: 0.267205918301487
# In iter_num: 1527, ABL: 40, ILD: -4.0, t_stim: 0.716636070963211
# In iter_num: 1542, ABL: 20, ILD: -8.0, t_stim: 0.397838538672511
# In iter_num: 1572, ABL: 20, ILD: 4.0, t_stim: 0.220367413553995
# In iter_num: 1311, ABL: 20, ILD: 16.0, t_stim: 0.204414894101672
# In iter_num: 1464, ABL: 60, ILD: 1.0, t_stim: 1.49992687480235
# In iter_num: 1248, ABL: 40, ILD: 4.0, t_stim: 0.880770182827308
# In iter_num: 1359, ABL: 40, ILD: -1.0, t_stim: 0.403215784545998
# In iter_num: 1392, ABL: 40, ILD: 4.0, t_stim: 0.940503854216029
# In iter_num: 1488, ABL: 40, ILD: -8.0, t_stim: 0.504236816169009
# In iter_num: 1185, ABL: 40, ILD: -1.0, t_stim: 0.743739490743421
# In iter_num: 1452, ABL: 60, ILD: -4.0, t_stim: 1.1423320506097
# In iter_num: 1329, ABL: 40, ILD: 8.0, t_stim: 0.23616725992048
# In iter_num: 1518, ABL: 20, ILD: 8.0, t_stim: 0.325483510432202
# In iter_num: 1170, ABL: 40, ILD: -16.0, t_stim: 0.233577930099425
# In iter_num: 1200, ABL: 20, ILD: -8.0, t_stim: 0.893033352565374
# In iter_num: 1437, ABL: 20, ILD: 4.0, t_stim: 0.305587228718554
# In iter_num: 1233, ABL: 40, ILD: -1.0, t_stim: 1.03773808817632
# In iter_num: 1620, ABL: 20, ILD: 16.0, t_stim: 0.628884225347661
# In iter_num: 1296, ABL: 20, ILD: 4.0, t_stim: 1.20844616899343
# In iter_num: 1530, ABL: 40, ILD: -4.0, t_stim: 0.236579728799748
# In iter_num: 1266, ABL: 20, ILD: -4.0, t_stim: 0.432252160067954
# In iter_num: 1605, ABL: 40, ILD: -8.0, t_stim: 0.360282574437226
# In iter_num: 1521, ABL: 60, ILD: 8.0, t_stim: 1.17853341015642
# In iter_num: 1347, ABL: 20, ILD: -1.0, t_stim: 1.05176948914848In iter_num: 1590, ABL: 40, ILD: -4.0, t_stim: 0.385992466569296
#
# In iter_num: 1314, ABL: 40, ILD: 1.0, t_stim: 0.438840881964403
# In iter_num: 1491, ABL: 20, ILD: -8.0, t_stim: 0.201704683984212
# In iter_num: 1500, ABL: 20, ILD: -8.0, t_stim: 0.426933024947306
# In iter_num: 1545, ABL: 20, ILD: -2.0, t_stim: 0.363155524993228
# In iter_num: 1668, ABL: 60, ILD: -8.0, t_stim: 0.459631504092402
# In iter_num: 1560, ABL: 40, ILD: -16.0, t_stim: 0.296740836274087
# In iter_num: 1101, ABL: 20, ILD: -8.0, t_stim: 0.287546765259895
# In iter_num: 1440, ABL: 60, ILD: -4.0, t_stim: 0.57014651607989
# In iter_num: 1575, ABL: 20, ILD: -1.0, t_stim: 0.387781291799011
# In iter_num: 1638, ABL: 20, ILD: -16.0, t_stim: 0.90592260792944
# In iter_num: 1653, ABL: 60, ILD: -1.0, t_stim: 0.913056825140215
# In iter_num: 1623, ABL: 40, ILD: 8.0, t_stim: 0.314034762241038
# In iter_num: 1395, ABL: 20, ILD: 8.0, t_stim: 0.225210022732205
# In iter_num: 1716, ABL: 20, ILD: -8.0, t_stim: 0.354187219268865
# In iter_num: 1251, ABL: 40, ILD: 8.0, t_stim: 0.509595189802497
# In iter_num: 1455, ABL: 20, ILD: 8.0, t_stim: 0.432063287924873
# In iter_num: 1362, ABL: 60, ILD: 8.0, t_stim: 0.797451217548039
# In iter_num: 1671, ABL: 40, ILD: -2.0, t_stim: 0.328070416514033
# In iter_num: 1701, ABL: 20, ILD: -1.0, t_stim: 0.41337429638595
# In iter_num: 1764, ABL: 60, ILD: -4.0, t_stim: 0.292329130439382
# In iter_num: 1548, ABL: 20, ILD: 16.0, t_stim: 0.286535483540114
# In iter_num: 1533, ABL: 40, ILD: -1.0, t_stim: 0.238980436168363
# In iter_num: 1593, ABL: 60, ILD: 2.0, t_stim: 0.740390127490245
# In iter_num: 990, ABL: 20, ILD: -1.0, t_stim: 0.213057906994069
# In iter_num: 1812, ABL: 40, ILD: 2.0, t_stim: 0.45325698193664
# In iter_num: 1203, ABL: 60, ILD: -1.0, t_stim: 0.947304938466323
# In iter_num: 1503, ABL: 60, ILD: -2.0, t_stim: 0.225253597539351
# In iter_num: 1734, ABL: 60, ILD: 8.0, t_stim: 1.11981847930785
# In iter_num: 1467, ABL: 60, ILD: -1.0, t_stim: 0.369666699877029
# In iter_num: 1626, ABL: 40, ILD: 4.0, t_stim: 0.61272300034566
# In iter_num: 1749, ABL: 40, ILD: 2.0, t_stim: 0.220367413553995
# In iter_num: 1299, ABL: 60, ILD: 2.0, t_stim: 0.694912076918941
# In iter_num: 1686, ABL: 60, ILD: -8.0, t_stim: 0.484945370728104
# In iter_num: 1458, ABL: 20, ILD: 4.0, t_stim: 0.40651379445764
# In iter_num: 1797, ABL: 60, ILD: -16.0, t_stim: 0.48484523852647
# In iter_num: 1674, ABL: 60, ILD: 16.0, t_stim: 0.650766747753536
# In iter_num: 1578, ABL: 40, ILD: 1.0, t_stim: 0.624145969052893
# In iter_num: 1860, ABL: 40, ILD: 1.0, t_stim: 0.380354163635337
# In iter_num: 1782, ABL: 60, ILD: -1.0, t_stim: 0.250226696769043
# In iter_num: 1563, ABL: 60, ILD: -8.0, t_stim: 0.920671261053883
# In iter_num: 1536, ABL: 40, ILD: -1.0, t_stim: 0.467851299214199
# In iter_num: 1656, ABL: 40, ILD: -2.0, t_stim: 1.34606329030253
# In iter_num: 1443, ABL: 20, ILD: 2.0, t_stim: 0.473486968862845
# In iter_num: 1551, ABL: 60, ILD: -1.0, t_stim: 0.699202040619057
# In iter_num: 1596, ABL: 20, ILD: -16.0, t_stim: 0.297887393640287
# In iter_num: 1737, ABL: 20, ILD: 1.0, t_stim: 0.289588262194584
# In iter_num: 1629, ABL: 40, ILD: -8.0, t_stim: 0.406576380475974
# In iter_num: 1641, ABL: 20, ILD: -4.0, t_stim: 0.231380847511043
# In iter_num: 1815, ABL: 20, ILD: 2.0, t_stim: 0.323191078404455
# In iter_num: 1608, ABL: 20, ILD: 1.0, t_stim: 0.217591540623958
# In iter_num: 1719, ABL: 40, ILD: -1.0, t_stim: 0.273335616537433
# In iter_num: 1830, ABL: 20, ILD: -8.0, t_stim: 0.575362308425197
# In iter_num: 1506, ABL: 40, ILD: 1.0, t_stim: 0.402001724799041
# In iter_num: 1677, ABL: 20, ILD: -8.0, t_stim: 0.255190343276917
# In iter_num: 1893, ABL: 40, ILD: 1.0, t_stim: 0.278083548347806
# In iter_num: 1956, ABL: 60, ILD: 8.0, t_stim: 0.605942305379672
# In iter_num: 1767, ABL: 20, ILD: 1.0, t_stim: 0.217674319704853
# In iter_num: 1104, ABL: 20, ILD: -16.0, t_stim: 0.326719776192736
# In iter_num: 1704, ABL: 40, ILD: 1.0, t_stim: 0.617947111007702
# In iter_num: 1845, ABL: 40, ILD: -1.0, t_stim: 0.366713406344742
# In iter_num: 1470, ABL: 20, ILD: 1.0, t_stim: 0.325685691307777
# In iter_num: 1632, ABL: 20, ILD: 4.0, t_stim: 0.604428626690912
# In iter_num: 1752, ABL: 40, ILD: -16.0, t_stim: 0.224876171311599
# In iter_num: 1680, ABL: 40, ILD: -1.0, t_stim: 0.282494457844098
# In iter_num: 1740, ABL: 60, ILD: -8.0, t_stim: 1.01290646452354
# In iter_num: 1539, ABL: 60, ILD: -2.0, t_stim: 0.653964950333171
# In iter_num: 1989, ABL: 60, ILD: -4.0, t_stim: 0.435077030603248
# In iter_num: 1599, ABL: 40, ILD: -2.0, t_stim: 0.987332349595582In iter_num: 1926, ABL: 40, ILD: 1.0, t_stim: 0.361139863828178
#
# In iter_num: 1644, ABL: 60, ILD: 1.0, t_stim: 0.452978308340527
# In iter_num: 1863, ABL: 60, ILD: 16.0, t_stim: 0.757842489043684
# In iter_num: 1689, ABL: 40, ILD: -8.0, t_stim: 0.798988332999384
# In iter_num: 1554, ABL: 60, ILD: 8.0, t_stim: 0.253617178299307
# In iter_num: 1722, ABL: 40, ILD: 1.0, t_stim: 0.338642214587751
# In iter_num: 1800, ABL: 40, ILD: 8.0, t_stim: 1.13822147425798
# In iter_num: 1581, ABL: 60, ILD: 8.0, t_stim: 0.687651192944972
# In iter_num: 1611, ABL: 40, ILD: 2.0, t_stim: 0.606544448754978
# In iter_num: 2052, ABL: 60, ILD: -1.0, t_stim: 0.594252861530848
# In iter_num: 1635, ABL: 20, ILD: 16.0, t_stim: 0.311500335047339
# In iter_num: 1683, ABL: 60, ILD: -8.0, t_stim: 0.373758436604799
# In iter_num: 1743, ABL: 60, ILD: -1.0, t_stim: 0.773183247387822
# In iter_num: 1959, ABL: 60, ILD: -8.0, t_stim: 0.862765447666469
# In iter_num: 1566, ABL: 20, ILD: 1.0, t_stim: 0.217362208454858
# In iter_num: 2148, ABL: 20, ILD: 2.0, t_stim: 1.31377951739033
# In iter_num: 2085, ABL: 40, ILD: -16.0, t_stim: 0.410823657601861
# In iter_num: 1785, ABL: 40, ILD: -16.0, t_stim: 1.08020469199582
# In iter_num: 1896, ABL: 40, ILD: -2.0, t_stim: 0.723903618603265
# In iter_num: 1818, ABL: 40, ILD: -8.0, t_stim: 0.234737683432891
# In iter_num: 1770, ABL: 60, ILD: -2.0, t_stim: 0.231363363892124
# In iter_num: 1833, ABL: 40, ILD: -8.0, t_stim: 0.393625352698875
# In iter_num: 1992, ABL: 20, ILD: -1.0, t_stim: 0.207062463509203
# In iter_num: 2118, ABL: 20, ILD: -2.0, t_stim: 0.206014264976922
# In iter_num: 1746, ABL: 20, ILD: 2.0, t_stim: 1.37512281653409
# In iter_num: 993, ABL: 20, ILD: -2.0, t_stim: 0.229975224699482
# In iter_num: 1848, ABL: 20, ILD: 8.0, t_stim: 0.287907983695516
# In iter_num: 1755, ABL: 40, ILD: 2.0, t_stim: 0.396313926807404
# In iter_num: 2022, ABL: 20, ILD: -16.0, t_stim: 0.368656532950936
# In iter_num: 1473, ABL: 20, ILD: 4.0, t_stim: 0.563152721715512
# In iter_num: 2088, ABL: 60, ILD: -4.0, t_stim: 0.289301685857677
# In iter_num: 1707, ABL: 40, ILD: 16.0, t_stim: 0.259364920249661
# In iter_num: 1602, ABL: 60, ILD: -4.0, t_stim: 0.224819862905509
# In iter_num: 1866, ABL: 20, ILD: -16.0, t_stim: 0.47166719719016
# In iter_num: 1692, ABL: 60, ILD: -8.0, t_stim: 0.462090820642952
# In iter_num: 2055, ABL: 60, ILD: 16.0, t_stim: 0.289273871105204
# In iter_num: 1725, ABL: 40, ILD: 8.0, t_stim: 0.315447886387936
# In iter_num: 1659, ABL: 20, ILD: -8.0, t_stim: 0.507930728945316
# In iter_num: 1614, ABL: 20, ILD: 4.0, t_stim: 0.351428543809106
# In iter_num: 2091, ABL: 40, ILD: -1.0, t_stim: 0.616418476995384
# In iter_num: 2181, ABL: 20, ILD: 4.0, t_stim: 0.546648264751218
# In iter_num: 1647, ABL: 60, ILD: -8.0, t_stim: 0.258466376895341
# In iter_num: 2121, ABL: 60, ILD: -1.0, t_stim: 0.292555063474723
# In iter_num: 1962, ABL: 40, ILD: -1.0, t_stim: 0.280356093870514
# In iter_num: 1569, ABL: 40, ILD: 1.0, t_stim: 0.406350759443804
# In iter_num: 1836, ABL: 20, ILD: 16.0, t_stim: 0.467406403796659
# In iter_num: 1584, ABL: 40, ILD: -1.0, t_stim: 0.643313329037626
# In iter_num: 1995, ABL: 20, ILD: 4.0, t_stim: 0.255435582824796
# In iter_num: 1821, ABL: 60, ILD: -2.0, t_stim: 0.599695509965734
# In iter_num: 1803, ABL: 20, ILD: -1.0, t_stim: 0.591993142977143
# In iter_num: 2151, ABL: 40, ILD: -4.0, t_stim: 0.460676547126285
# In iter_num: 1929, ABL: 60, ILD: 2.0, t_stim: 0.5436333769884
# In iter_num: 1788, ABL: 40, ILD: 2.0, t_stim: 0.899474567828236
# In iter_num: 1710, ABL: 60, ILD: 1.0, t_stim: 0.403200530452781In iter_num: 2124, ABL: 60, ILD: 8.0, t_stim: 0.374952373881207
#
# In iter_num: 1851, ABL: 40, ILD: 4.0, t_stim: 0.378617238718802
# In iter_num: 1899, ABL: 60, ILD: 4.0, t_stim: 0.325147920136092
# In iter_num: 2025, ABL: 60, ILD: -4.0, t_stim: 0.54642608403763
# In iter_num: 2184, ABL: 60, ILD: 16.0, t_stim: 0.200574604204541
# In iter_num: 2094, ABL: 60, ILD: 2.0, t_stim: 0.257635927485901
# In iter_num: 1773, ABL: 40, ILD: -4.0, t_stim: 0.670430982251717
# In iter_num: 1695, ABL: 60, ILD: -4.0, t_stim: 0.294390015456312
# In iter_num: 2058, ABL: 60, ILD: 8.0, t_stim: 0.604860057950623
# In iter_num: 2244, ABL: 60, ILD: -16.0, t_stim: 0.239431768476373
# In iter_num: 1965, ABL: 20, ILD: -1.0, t_stim: 0.354274154985735
# In iter_num: 1758, ABL: 60, ILD: -4.0, t_stim: 0.281697880426657
# In iter_num: 2097, ABL: 40, ILD: 8.0, t_stim: 0.677988544839823
# In iter_num: 2127, ABL: 20, ILD: -1.0, t_stim: 0.517350057269196
# In iter_num: 2187, ABL: 40, ILD: -16.0, t_stim: 0.412143289787256
# In iter_num: 1650, ABL: 60, ILD: -16.0, t_stim: 0.476905471834898
# In iter_num: 1728, ABL: 20, ILD: 8.0, t_stim: 1.09055669354305
# In iter_num: 1869, ABL: 20, ILD: 16.0, t_stim: 0.963129816178578
# In iter_num: 2154, ABL: 60, ILD: 1.0, t_stim: 0.348468669005379
# In iter_num: 2028, ABL: 40, ILD: 1.0, t_stim: 0.973835431073298
# In iter_num: 1998, ABL: 60, ILD: 8.0, t_stim: 0.227764774546291
# In iter_num: 1824, ABL: 60, ILD: -1.0, t_stim: 0.348468669005379
# In iter_num: 2190, ABL: 40, ILD: -8.0, t_stim: 0.22039736767334
# In iter_num: 2100, ABL: 40, ILD: 4.0, t_stim: 0.312335214451962
# In iter_num: 1839, ABL: 40, ILD: -16.0, t_stim: 0.40739057818126
# In iter_num: 1902, ABL: 40, ILD: -8.0, t_stim: 1.02887045080862
# In iter_num: 2130, ABL: 60, ILD: 16.0, t_stim: 0.51891226633099
# In iter_num: 1587, ABL: 20, ILD: 1.0, t_stim: 0.370147178812813
# In iter_num: 2061, ABL: 20, ILD: 8.0, t_stim: 0.423480529746182
# In iter_num: 1662, ABL: 20, ILD: 4.0, t_stim: 0.318253758031799
# In iter_num: 2277, ABL: 20, ILD: 8.0, t_stim: 0.632004327636982
# In iter_num: 1617, ABL: 40, ILD: -2.0, t_stim: 0.345128606198261
# In iter_num: 1107, ABL: 60, ILD: -16.0, t_stim: 0.594165033898221
# In iter_num: 1806, ABL: 20, ILD: 2.0, t_stim: 0.580587863446034
# In iter_num: 1968, ABL: 40, ILD: 16.0, t_stim: 0.214393575856026
# In iter_num: 1698, ABL: 60, ILD: -4.0, t_stim: 0.241187490235941
# In iter_num: 2193, ABL: 40, ILD: 8.0, t_stim: 0.568676024589612
# In iter_num: 1932, ABL: 60, ILD: -1.0, t_stim: 0.753349878987967
# In iter_num: 1791, ABL: 20, ILD: -4.0, t_stim: 0.639658679310629
# In iter_num: 2340, ABL: 20, ILD: 16.0, t_stim: 0.83960433086363
# In iter_num: 2247, ABL: 20, ILD: 8.0, t_stim: 0.235240861569907
# In iter_num: 2133, ABL: 60, ILD: -1.0, t_stim: 0.859717780808433
# In iter_num: 2103, ABL: 20, ILD: -1.0, t_stim: 0.208591997166199
# In iter_num: 2001, ABL: 40, ILD: 2.0, t_stim: 0.29161407081972
# In iter_num: 2064, ABL: 40, ILD: -1.0, t_stim: 0.299872659875759
# In iter_num: 1776, ABL: 60, ILD: -1.0, t_stim: 0.211815059082304
# In iter_num: 2157, ABL: 40, ILD: -4.0, t_stim: 0.700914166223259
# In iter_num: 2031, ABL: 40, ILD: -4.0, t_stim: 0.590986154794583
# In iter_num: 2196, ABL: 20, ILD: -16.0, t_stim: 0.455688326084966
# In iter_num: 1971, ABL: 20, ILD: 16.0, t_stim: 0.523069696168118
# In iter_num: 1854, ABL: 60, ILD: -4.0, t_stim: 0.579752311823229
# In iter_num: 2280, ABL: 40, ILD: -8.0, t_stim: 0.407876012062113
# In iter_num: 1872, ABL: 60, ILD: 4.0, t_stim: 0.503220929270467
# In iter_num: 2106, ABL: 40, ILD: -1.0, t_stim: 0.517350057269196
# In iter_num: 1827, ABL: 60, ILD: -1.0, t_stim: 0.802442439400085
# In iter_num: 2310, ABL: 20, ILD: -4.0, t_stim: 0.26537911623541
# In iter_num: 1731, ABL: 40, ILD: 2.0, t_stim: 2.13601971267061
# In iter_num: 1761, ABL: 60, ILD: -4.0, t_stim: 0.397261154346403
# In iter_num: 2199, ABL: 40, ILD: 4.0, t_stim: 0.203397172344769
# In iter_num: 1713, ABL: 20, ILD: -4.0, t_stim: 0.283512771251414
# In iter_num: 2136, ABL: 20, ILD: 2.0, t_stim: 0.313119238142635
# In iter_num: 2250, ABL: 20, ILD: 1.0, t_stim: 0.9264013688363
# In iter_num: 2109, ABL: 20, ILD: -8.0, t_stim: 0.474034437802993
# In iter_num: 2067, ABL: 40, ILD: -2.0, t_stim: 0.346380795871734
# In iter_num: 1665, ABL: 60, ILD: -16.0, t_stim: 0.786199979561668
# In iter_num: 2436, ABL: 40, ILD: -2.0, t_stim: 0.47099781775283
# In iter_num: 1809, ABL: 60, ILD: -4.0, t_stim: 0.418621324352753
# In iter_num: 1842, ABL: 40, ILD: 1.0, t_stim: 0.359091285866076
# In iter_num: 1779, ABL: 20, ILD: 8.0, t_stim: 1.48064043486767
# In iter_num: 2004, ABL: 20, ILD: 8.0, t_stim: 0.271626209739328
# In iter_num: 1974, ABL: 20, ILD: 16.0, t_stim: 0.627561027902584
# In iter_num: 2034, ABL: 20, ILD: -2.0, t_stim: 0.370221143144004
# In iter_num: 1905, ABL: 20, ILD: 1.0, t_stim: 0.32035063858411
# In iter_num: 2202, ABL: 20, ILD: 16.0, t_stim: 0.713370898717797
# In iter_num: 2373, ABL: 20, ILD: 4.0, t_stim: 0.572076800475349
# In iter_num: 2139, ABL: 40, ILD: 4.0, t_stim: 0.680564351551283
# In iter_num: 2112, ABL: 60, ILD: 4.0, t_stim: 0.380005041964132
# In iter_num: 2343, ABL: 40, ILD: 1.0, t_stim: 1.37040514032199
# In iter_num: 2160, ABL: 20, ILD: -1.0, t_stim: 1.26807872406216
# In iter_num: 2469, ABL: 40, ILD: 8.0, t_stim: 0.396655911220706
# In iter_num: 2532, ABL: 20, ILD: -8.0, t_stim: 0.201522392766361
# In iter_num: 1935, ABL: 40, ILD: -4.0, t_stim: 0.728706990201537
# In iter_num: 2406, ABL: 60, ILD: 1.0, t_stim: 0.26347234782401
# In iter_num: 2283, ABL: 60, ILD: -4.0, t_stim: 0.35450009895249
# In iter_num: 2313, ABL: 60, ILD: 4.0, t_stim: 0.510719373774806
# In iter_num: 2205, ABL: 20, ILD: 4.0, t_stim: 0.469662075834749
# In iter_num: 1857, ABL: 60, ILD: -8.0, t_stim: 0.305327680326257
# In iter_num: 2115, ABL: 40, ILD: 4.0, t_stim: 0.757544736881046
# In iter_num: 2253, ABL: 20, ILD: 8.0, t_stim: 1.20946612909824
# In iter_num: 2070, ABL: 60, ILD: 2.0, t_stim: 0.232818624728666
# In iter_num: 1977, ABL: 20, ILD: 8.0, t_stim: 1.68187004529199In iter_num: 2142, ABL: 20, ILD: 8.0, t_stim: 0.49281772746916
#
# In iter_num: 2007, ABL: 40, ILD: 16.0, t_stim: 0.599446693891385
# In iter_num: 2628, ABL: 60, ILD: -4.0, t_stim: 0.500185416009988
# In iter_num: 2214, ABL: 20, ILD: 4.0, t_stim: 0.583437360763697
# In iter_num: 2037, ABL: 20, ILD: -2.0, t_stim: 0.478336513504159
# In iter_num: 2163, ABL: 20, ILD: 2.0, t_stim: 0.634369873471986
# In iter_num: 1875, ABL: 40, ILD: 1.0, t_stim: 0.710998025880333
# In iter_num: 2535, ABL: 40, ILD: -16.0, t_stim: 1.23521398655714
# In iter_num: 2565, ABL: 40, ILD: -2.0, t_stim: 0.254080633379353
# In iter_num: 2145, ABL: 60, ILD: 2.0, t_stim: 0.336373399259239
# In iter_num: 2724, ABL: 40, ILD: -2.0, t_stim: 0.460478272895525
# In iter_num: 2502, ABL: 60, ILD: -8.0, t_stim: 0.415031733829302
# In iter_num: 2208, ABL: 40, ILD: -4.0, t_stim: 0.560204585142913
# In iter_num: 2346, ABL: 40, ILD: 8.0, t_stim: 0.442244297752276
# In iter_num: 2661, ABL: 60, ILD: 8.0, t_stim: 0.624444057253778
# In iter_num: 2631, ABL: 20, ILD: -4.0, t_stim: 0.462870355851541
# In iter_num: 2376, ABL: 20, ILD: -4.0, t_stim: 0.579968019639652
# In iter_num: 1908, ABL: 60, ILD: -4.0, t_stim: 0.576865539309569
# In iter_num: 2286, ABL: 40, ILD: -1.0, t_stim: 0.425293928381531
# In iter_num: 2073, ABL: 60, ILD: 8.0, t_stim: 0.711561942152541
# In iter_num: 2409, ABL: 20, ILD: -2.0, t_stim: 0.442462113078961
# In iter_num: 2598, ABL: 20, ILD: 8.0, t_stim: 0.269125771471648
# In iter_num: 1794, ABL: 60, ILD: -16.0, t_stim: 0.304069420525115
# In iter_num: 2757, ABL: 40, ILD: -2.0, t_stim: 0.396752565025287
# In iter_num: 1938, ABL: 60, ILD: -8.0, t_stim: 0.516645251529635
# In iter_num: 2472, ABL: 20, ILD: -8.0, t_stim: 0.687809992481686
# In iter_num: 2166, ABL: 40, ILD: 16.0, t_stim: 0.509070558425417
# In iter_num: 2820, ABL: 40, ILD: -8.0, t_stim: 0.376799596757435
# In iter_num: 2010, ABL: 20, ILD: 1.0, t_stim: 0.210654191135554
# In iter_num: 2694, ABL: 20, ILD: 1.0, t_stim: 0.243896106572399
# In iter_num: 2211, ABL: 20, ILD: 2.0, t_stim: 1.34673865761653
# In iter_num: 2256, ABL: 20, ILD: 2.0, t_stim: 0.44558564888694
# In iter_num: 2634, ABL: 60, ILD: -1.0, t_stim: 0.267002165232008
# In iter_num: 2439, ABL: 40, ILD: 2.0, t_stim: 0.597795403405397
# In iter_num: 2538, ABL: 60, ILD: 16.0, t_stim: 0.439421751638677
# In iter_num: 2316, ABL: 60, ILD: -4.0, t_stim: 0.442479486190662
# In iter_num: 2040, ABL: 60, ILD: 8.0, t_stim: 0.400227752428836
# In iter_num: 1980, ABL: 40, ILD: -8.0, t_stim: 0.58572648130576
# In iter_num: 2790, ABL: 40, ILD: 4.0, t_stim: 0.268714812567927
# In iter_num: 1878, ABL: 20, ILD: -8.0, t_stim: 0.261151460833622
# In iter_num: 2349, ABL: 20, ILD: -1.0, t_stim: 0.357038917523074
# In iter_num: 2637, ABL: 20, ILD: 16.0, t_stim: 0.350790481886862
# ...
# In iter_num: 49443, ABL: 40, ILD: -16.0, t_stim: 0.881604463771676
# In iter_num: 49266, ABL: 20, ILD: 1.0, t_stim: 0.382506651572834
# In iter_num: 49491, ABL: 60, ILD: -4.0, t_stim: 0.494768972328219
# In iter_num: 45759, ABL: 60, ILD: 8.0, t_stim: 0.321540830275071
# In iter_num: 49203, ABL: 40, ILD: -2.0, t_stim: 0.281697880426657
# In iter_num: 49470, ABL: 40, ILD: 1.0, t_stim: 1.00326247990363
# In iter_num: 49398, ABL: 20, ILD: -2.0, t_stim: 0.649787083146008
# In iter_num: 49302, ABL: 20, ILD: 4.0, t_stim: 0.24788389908367
# In iter_num: 49404, ABL: 40, ILD: -8.0, t_stim: 0.642575174436828
# In iter_num: 49344, ABL: 60, ILD: 8.0, t_stim: 0.321257892782316
# In iter_num: 49293, ABL: 20, ILD: -2.0, t_stim: 0.473692769329742In iter_num: 49530, ABL: 60, ILD: 8.0, t_stim: 0.378759014189651
#
# In iter_num: 49329, ABL: 40, ILD: -8.0, t_stim: 0.232660281075036
# In iter_num: 49479, ABL: 40, ILD: -1.0, t_stim: 0.380441765695324
# In iter_num: 49188, ABL: 20, ILD: 1.0, t_stim: 0.335974385416034
# In iter_num: 49446, ABL: 60, ILD: -8.0, t_stim: 0.223053307324591
# In iter_num: 49431, ABL: 20, ILD: -1.0, t_stim: 1.49142217375858
# In iter_num: 49569, ABL: 60, ILD: 16.0, t_stim: 0.622748104413102
# In iter_num: 49518, ABL: 20, ILD: 1.0, t_stim: 0.502537526714698
# In iter_num: 49473, ABL: 20, ILD: 1.0, t_stim: 0.228627182781479
# In iter_num: 49455, ABL: 20, ILD: -2.0, t_stim: 0.269216901756463
# In iter_num: 49545, ABL: 20, ILD: 8.0, t_stim: 0.522077659606612
# In iter_num: 49506, ABL: 60, ILD: 8.0, t_stim: 0.375278535980224
# In iter_num: 49368, ABL: 40, ILD: 8.0, t_stim: 0.607559551817033
# In iter_num: 46008, ABL: 20, ILD: -8.0, t_stim: 0.423868894206813
# In iter_num: 45762, ABL: 20, ILD: -16.0, t_stim: 0.217714316350017
# In iter_num: 49419, ABL: 40, ILD: -16.0, t_stim: 0.216265924271087
# In iter_num: 49230, ABL: 20, ILD: 8.0, t_stim: 1.30124079165089
# In iter_num: 49494, ABL: 60, ILD: 4.0, t_stim: 0.666646241505236
# In iter_num: 49449, ABL: 20, ILD: 4.0, t_stim: 0.489558043308735
# In iter_num: 49476, ABL: 40, ILD: 16.0, t_stim: 0.327674964311969
# In iter_num: 49548, ABL: 20, ILD: 8.0, t_stim: 1.09230221424979
# In iter_num: 49152, ABL: 20, ILD: 16.0, t_stim: 0.383798715261559
# In iter_num: 49380, ABL: 20, ILD: -1.0, t_stim: 0.57296474751851
# In iter_num: 49557, ABL: 20, ILD: 1.0, t_stim: 0.527244248573025
# In iter_num: 49242, ABL: 40, ILD: 4.0, t_stim: 1.08214140351904
# In iter_num: 49347, ABL: 40, ILD: 8.0, t_stim: 0.22412890945497
# In iter_num: 49305, ABL: 60, ILD: 1.0, t_stim: 0.651215188954577
# In iter_num: 49572, ABL: 60, ILD: -16.0, t_stim: 0.246750731027031
# In iter_num: 49596, ABL: 40, ILD: -1.0, t_stim: 0.443520844447273
# In iter_num: 49608, ABL: 40, ILD: -1.0, t_stim: 0.223133865658574
# In iter_num: 49269, ABL: 60, ILD: 16.0, t_stim: 0.488200443318874
# In iter_num: 49332, ABL: 40, ILD: -16.0, t_stim: 0.210440413401579
# In iter_num: 49191, ABL: 40, ILD: -16.0, t_stim: 0.410035630455291
# In iter_num: 49584, ABL: 40, ILD: 8.0, t_stim: 0.415889010517075
# In iter_num: 49533, ABL: 40, ILD: -4.0, t_stim: 0.40140670856375
# In iter_num: 49434, ABL: 60, ILD: 16.0, t_stim: 0.207759627415605
# In iter_num: 45222, ABL: 60, ILD: 8.0, t_stim: 0.37099734107504
# In iter_num: 49509, ABL: 20, ILD: -1.0, t_stim: 0.438864467223014
# In iter_num: 49647, ABL: 40, ILD: -16.0, t_stim: 0.202614130633179
# In iter_num: 49551, ABL: 20, ILD: -4.0, t_stim: 0.534534617808886
# In iter_num: 49521, ABL: 20, ILD: -2.0, t_stim: 0.29230055252817
# In iter_num: 49407, ABL: 20, ILD: -4.0, t_stim: 1.15225452167132
# In iter_num: 49422, ABL: 40, ILD: 16.0, t_stim: 0.282510833081777
# In iter_num: 49623, ABL: 20, ILD: 1.0, t_stim: 0.429211974454764
# In iter_num: 49599, ABL: 60, ILD: -2.0, t_stim: 0.857169557037719
# In iter_num: 49686, ABL: 60, ILD: -8.0, t_stim: 0.333561278804696
# In iter_num: 46011, ABL: 40, ILD: -8.0, t_stim: 0.303715312474346
# In iter_num: 49458, ABL: 40, ILD: 16.0, t_stim: 0.535501573857922
# In iter_num: 49674, ABL: 40, ILD: -1.0, t_stim: 0.458051347457876
# In iter_num: 49497, ABL: 20, ILD: 4.0, t_stim: 0.778272653204199
# In iter_num: 49560, ABL: 40, ILD: 8.0, t_stim: 0.262829694372929
# In iter_num: 49575, ABL: 60, ILD: -2.0, t_stim: 1.04038556393482
# In iter_num: 49383, ABL: 20, ILD: 1.0, t_stim: 0.74165887947704
# In iter_num: 49554, ABL: 60, ILD: 2.0, t_stim: 0.504222188642552
# In iter_num: 49371, ABL: 40, ILD: -8.0, t_stim: 0.80055962641938
# In iter_num: 49308, ABL: 20, ILD: -8.0, t_stim: 0.36277109147739
# In iter_num: 49512, ABL: 60, ILD: -1.0, t_stim: 0.749002917553838
# In iter_num: 49602, ABL: 40, ILD: 2.0, t_stim: 0.204149160680096
# In iter_num: 49635, ABL: 40, ILD: -1.0, t_stim: 0.416791438104723
# In iter_num: 49662, ABL: 40, ILD: -4.0, t_stim: 0.683684566392498
# In iter_num: 49626, ABL: 40, ILD: 2.0, t_stim: 0.755088987844139
# In iter_num: 49587, ABL: 60, ILD: -16.0, t_stim: 0.823282091611552
# In iter_num: 49713, ABL: 20, ILD: -8.0, t_stim: 0.908158324833478
# In iter_num: 49482, ABL: 60, ILD: -16.0, t_stim: 0.575388567814968
# In iter_num: 49437, ABL: 60, ILD: 8.0, t_stim: 0.431674955245339
# In iter_num: 44703, ABL: 20, ILD: -4.0, t_stim: 0.527128218994291
# In iter_num: 49701, ABL: 40, ILD: -1.0, t_stim: 0.367044762047521
# In iter_num: 49650, ABL: 60, ILD: 16.0, t_stim: 0.752071040895121
# In iter_num: 49725, ABL: 60, ILD: 8.0, t_stim: 0.515868536887483
# In iter_num: 49611, ABL: 20, ILD: 16.0, t_stim: 0.427734113612012
# In iter_num: 49536, ABL: 20, ILD: 1.0, t_stim: 0.208239176255093
# In iter_num: 49563, ABL: 40, ILD: -16.0, t_stim: 0.534799767250076
# In iter_num: 49605, ABL: 20, ILD: 2.0, t_stim: 0.284753399319815
# In iter_num: 49461, ABL: 40, ILD: -1.0, t_stim: 0.590759275254175
# In iter_num: 49629, ABL: 40, ILD: -4.0, t_stim: 0.440446934586712
# In iter_num: 49752, ABL: 40, ILD: 4.0, t_stim: 0.294582050838137
# In iter_num: 49689, ABL: 20, ILD: -16.0, t_stim: 0.225836959513348
# In iter_num: 49677, ABL: 40, ILD: -8.0, t_stim: 0.236431060598559
# In iter_num: 49578, ABL: 40, ILD: 4.0, t_stim: 0.294742960207936
# In iter_num: 49410, ABL: 40, ILD: -1.0, t_stim: 0.637314165031525
# In iter_num: 49524, ABL: 60, ILD: 16.0, t_stim: 0.396054880979793
# In iter_num: 46014, ABL: 60, ILD: -4.0, t_stim: 0.271392979290421
# In iter_num: 49764, ABL: 40, ILD: 8.0, t_stim: 0.418892166727581
# In iter_num: 49728, ABL: 20, ILD: -2.0, t_stim: 0.289957271063616
# In iter_num: 49425, ABL: 20, ILD: 2.0, t_stim: 0.680215743046591
# In iter_num: 49515, ABL: 20, ILD: -16.0, t_stim: 0.216932293153137
# In iter_num: 45225, ABL: 60, ILD: 16.0, t_stim: 0.384293154531834
# In iter_num: 49632, ABL: 40, ILD: -4.0, t_stim: 0.263134189560084
# In iter_num: 49566, ABL: 40, ILD: 8.0, t_stim: 0.825059336708348
# In iter_num: 49590, ABL: 40, ILD: -16.0, t_stim: 0.676940850320343
# In iter_num: 49665, ABL: 60, ILD: 8.0, t_stim: 0.206349484976546
# In iter_num: 49791, ABL: 20, ILD: -1.0, t_stim: 0.223058238574068
# In iter_num: 49716, ABL: 60, ILD: 4.0, t_stim: 0.243382781508725
# In iter_num: 49740, ABL: 40, ILD: 4.0, t_stim: 0.308167656206854
# In iter_num: 49704, ABL: 20, ILD: -16.0, t_stim: 0.214409543922884
# In iter_num: 49500, ABL: 60, ILD: -8.0, t_stim: 0.258681578621945
# In iter_num: 49803, ABL: 40, ILD: 4.0, t_stim: 0.253468906371265
# In iter_num: 49731, ABL: 20, ILD: 2.0, t_stim: 0.264387696368359
# In iter_num: 49386, ABL: 40, ILD: 4.0, t_stim: 0.373237769404954
# In iter_num: 49638, ABL: 20, ILD: -8.0, t_stim: 0.266036349850974
# In iter_num: 49485, ABL: 60, ILD: -1.0, t_stim: 0.286911373539559
# In iter_num: 49653, ABL: 20, ILD: -4.0, t_stim: 0.568536990874981
# In iter_num: 49581, ABL: 40, ILD: -2.0, t_stim: 0.732786114852068
# In iter_num: 49614, ABL: 60, ILD: 2.0, t_stim: 0.2458158995462
# In iter_num: 49539, ABL: 20, ILD: 1.0, t_stim: 0.287907983695516
# In iter_num: 49794, ABL: 20, ILD: -1.0, t_stim: 0.268904251428284
# In iter_num: 49779, ABL: 60, ILD: 4.0, t_stim: 0.96093086421652
# In iter_num: 49842, ABL: 60, ILD: 16.0, t_stim: 0.203598820592267
# In iter_num: 49692, ABL: 60, ILD: -2.0, t_stim: 0.410823657601861
# In iter_num: 49830, ABL: 60, ILD: 1.0, t_stim: 0.206692202776328
# In iter_num: 46017, ABL: 20, ILD: 1.0, t_stim: 0.866554665184411
# In iter_num: 49767, ABL: 20, ILD: 4.0, t_stim: 1.51002772330973
# In iter_num: 49734, ABL: 40, ILD: -1.0, t_stim: 0.574971198869792
# In iter_num: 49680, ABL: 60, ILD: -2.0, t_stim: 0.241180169206368
# In iter_num: 49464, ABL: 20, ILD: 2.0, t_stim: 0.531939416578212
# In iter_num: 49833, ABL: 40, ILD: 16.0, t_stim: 0.478257643832741
# In iter_num: 49755, ABL: 40, ILD: -2.0, t_stim: 0.913157327169391
# In iter_num: 49743, ABL: 20, ILD: 2.0, t_stim: 0.222456030994795
# In iter_num: 49527, ABL: 60, ILD: 16.0, t_stim: 0.43624987466477
# In iter_num: 49668, ABL: 20, ILD: 8.0, t_stim: 0.243692862252689
# In iter_num: 49488, ABL: 20, ILD: -16.0, t_stim: 0.225479719312295
# In iter_num: 49797, ABL: 40, ILD: 4.0, t_stim: 0.940582012644251
# In iter_num: 44706, ABL: 20, ILD: -2.0, t_stim: 0.334809753512274
# In iter_num: 49737, ABL: 60, ILD: 8.0, t_stim: 0.822632987285249
# In iter_num: 49707, ABL: 60, ILD: 16.0, t_stim: 0.598458559935255
# In iter_num: 49806, ABL: 20, ILD: -1.0, t_stim: 0.219390795154792
# In iter_num: 49857, ABL: 40, ILD: 8.0, t_stim: 0.216920097002833
# In iter_num: 49593, ABL: 20, ILD: 8.0, t_stim: 1.20215350357999
# In iter_num: 49881, ABL: 20, ILD: 4.0, t_stim: 1.21439153571513
# In iter_num: 49656, ABL: 40, ILD: 2.0, t_stim: 0.766174348044931
# In iter_num: 49641, ABL: 20, ILD: 8.0, t_stim: 0.448220143777734
# In iter_num: 49818, ABL: 60, ILD: 16.0, t_stim: 0.558452066486184
# In iter_num: 49542, ABL: 60, ILD: 2.0, t_stim: 0.23968798582278
# In iter_num: 49836, ABL: 20, ILD: 8.0, t_stim: 0.242605369179488
# In iter_num: 49869, ABL: 60, ILD: -4.0, t_stim: 0.350239342133577
# In iter_num: 49503, ABL: 40, ILD: 8.0, t_stim: 0.248081438294795
# In iter_num: 49908, ABL: 40, ILD: 2.0, t_stim: 0.424850754314558
# In iter_num: 49719, ABL: 40, ILD: 8.0, t_stim: 0.48053352140094
# In iter_num: 49800, ABL: 20, ILD: 4.0, t_stim: 0.346890493779935
# In iter_num: 49839, ABL: 40, ILD: 8.0, t_stim: 0.324712157793577
# In iter_num: 49920, ABL: 40, ILD: 2.0, t_stim: 0.402629590276672
# In iter_num: 49782, ABL: 60, ILD: -16.0, t_stim: 0.694014756129088
# In iter_num: 49770, ABL: 20, ILD: -4.0, t_stim: 0.479729807466942
# In iter_num: 49821, ABL: 60, ILD: 16.0, t_stim: 0.251962701478705
# In iter_num: 49845, ABL: 20, ILD: 2.0, t_stim: 0.649762333599867
# In iter_num: 49746, ABL: 20, ILD: 4.0, t_stim: 1.29752088063824
# In iter_num: 49617, ABL: 20, ILD: -8.0, t_stim: 0.489744731885118
# In iter_num: 49860, ABL: 60, ILD: -4.0, t_stim: 0.477118811691543
# In iter_num: 49911, ABL: 20, ILD: 2.0, t_stim: 0.304609560507449
# In iter_num: 49884, ABL: 20, ILD: -4.0, t_stim: 0.59294463880761
# In iter_num: 49695, ABL: 20, ILD: -16.0, t_stim: 0.417154256508877
# In iter_num: 49710, ABL: 20, ILD: 2.0, t_stim: 0.368845237976771
# In iter_num: 49959, ABL: 20, ILD: -8.0, t_stim: 0.680701702042732
# In iter_num: 49947, ABL: 60, ILD: -16.0, t_stim: 0.441465511951339
# In iter_num: 49896, ABL: 20, ILD: 4.0, t_stim: 0.523082656762704
# In iter_num: 49671, ABL: 60, ILD: 16.0, t_stim: 0.349985599940286
# In iter_num: 49872, ABL: 60, ILD: -2.0, t_stim: 0.35105749218458
# In iter_num: 45228, ABL: 60, ILD: -16.0, t_stim: 0.276286494302502
# In iter_num: 49758, ABL: 60, ILD: -1.0, t_stim: 0.286302644734977
# In iter_num: 49998, ABL: 60, ILD: -8.0, t_stim: 0.865147205698045
# In iter_num: 49986, ABL: 60, ILD: 2.0, t_stim: 0.969883463652619
# In iter_num: 49644, ABL: 20, ILD: 2.0, t_stim: 1.39358678543846
# In iter_num: 49914, ABL: 60, ILD: -4.0, t_stim: 0.870417630434261
# In iter_num: 49935, ABL: 20, ILD: -8.0, t_stim: 0.294604502036451
# In iter_num: 49824, ABL: 40, ILD: 16.0, t_stim: 0.322818908730626
# In iter_num: 49659, ABL: 60, ILD: 4.0, t_stim: 0.828028715609499
# In iter_num: 44709, ABL: 60, ILD: -16.0, t_stim: 1.10680383832005
# In iter_num: 49722, ABL: 60, ILD: 8.0, t_stim: 1.00902443065064
# In iter_num: 49698, ABL: 20, ILD: 16.0, t_stim: 0.421938333441558
# In iter_num: 49683, ABL: 60, ILD: -4.0, t_stim: 0.824063878879047
# In iter_num: 49962, ABL: 20, ILD: 1.0, t_stim: 0.29483062729622
# In iter_num: 49917, ABL: 60, ILD: 1.0, t_stim: 0.382616266804167
# In iter_num: 49848, ABL: 40, ILD: -16.0, t_stim: 0.200500953773451
# In iter_num: 49887, ABL: 20, ILD: 16.0, t_stim: 0.349976824909587
# In iter_num: 49899, ABL: 60, ILD: -1.0, t_stim: 0.492003357629983In iter_num: 49809, ABL: 60, ILD: 2.0, t_stim: 0.236533474362525
#
# In iter_num: 49974, ABL: 40, ILD: -1.0, t_stim: 0.676940850320343
# In iter_num: 49863, ABL: 60, ILD: 16.0, t_stim: 0.601721354213938
# In iter_num: 49773, ABL: 60, ILD: 8.0, t_stim: 0.328626566637366
# In iter_num: 49923, ABL: 20, ILD: 16.0, t_stim: 0.656594651640591
# In iter_num: 49785, ABL: 40, ILD: 4.0, t_stim: 0.590949100105236
# In iter_num: 49965, ABL: 40, ILD: -1.0, t_stim: 0.375694065215926
# In iter_num: 45231, ABL: 60, ILD: 8.0, t_stim: 0.649833011422615
# In iter_num: 49827, ABL: 60, ILD: -2.0, t_stim: 0.455450239284577
# In iter_num: 49890, ABL: 60, ILD: -16.0, t_stim: 0.4313863585956
# In iter_num: 44712, ABL: 40, ILD: -2.0, t_stim: 0.27255708046968
# In iter_num: 49761, ABL: 20, ILD: 1.0, t_stim: 0.363824376173585
# In iter_num: 49989, ABL: 20, ILD: -16.0, t_stim: 0.404437722089714
# In iter_num: 49875, ABL: 20, ILD: -2.0, t_stim: 0.224289303560304
# In iter_num: 49749, ABL: 40, ILD: -4.0, t_stim: 0.324729721108529
# In iter_num: 49938, ABL: 20, ILD: 1.0, t_stim: 0.305627263633477
# In iter_num: 49866, ABL: 40, ILD: 8.0, t_stim: 0.793763856947948
# In iter_num: 49812, ABL: 40, ILD: 1.0, t_stim: 0.437914440396757
# In iter_num: 49950, ABL: 60, ILD: -16.0, t_stim: 0.338981968080307
# In iter_num: 49926, ABL: 40, ILD: 16.0, t_stim: 0.554523083297903
# In iter_num: 49968, ABL: 60, ILD: -2.0, t_stim: 0.333071378214562
# In iter_num: 49620, ABL: 20, ILD: 2.0, t_stim: 0.208297406489557
# In iter_num: 49893, ABL: 20, ILD: 8.0, t_stim: 1.21700917014741
# In iter_num: 44715, ABL: 20, ILD: 8.0, t_stim: 0.373237769404954
# In iter_num: 49788, ABL: 20, ILD: 16.0, t_stim: 0.589053305657251
# In iter_num: 49878, ABL: 20, ILD: 16.0, t_stim: 0.204498052183452
# In iter_num: 49971, ABL: 20, ILD: 2.0, t_stim: 0.451896257968087
# In iter_num: 49929, ABL: 20, ILD: -1.0, t_stim: 0.443011400467349
# In iter_num: 49851, ABL: 40, ILD: 1.0, t_stim: 0.213738526235369
# In iter_num: 49815, ABL: 40, ILD: 1.0, t_stim: 1.06960102428955
# In iter_num: 49776, ABL: 20, ILD: 16.0, t_stim: 0.395476401744452
# In iter_num: 44718, ABL: 20, ILD: 8.0, t_stim: 1.07301290880396
# In iter_num: 49977, ABL: 40, ILD: 16.0, t_stim: 0.211291799560437
# In iter_num: 45234, ABL: 60, ILD: 4.0, t_stim: 0.366644375216262
# In iter_num: 49992, ABL: 20, ILD: -16.0, t_stim: 0.274728182733722
# In iter_num: 49902, ABL: 60, ILD: 8.0, t_stim: 0.516779478608288In iter_num: 49932, ABL: 40, ILD: -16.0, t_stim: 0.240363659415198
#
# In iter_num: 44721, ABL: 20, ILD: 8.0, t_stim: 0.389437645386092
# In iter_num: 49941, ABL: 20, ILD: 8.0, t_stim: 0.289505296077575
# In iter_num: 44724, ABL: 60, ILD: 4.0, t_stim: 0.20035358692221
# In iter_num: 49953, ABL: 40, ILD: 16.0, t_stim: 0.35918605269196
# In iter_num: 49854, ABL: 20, ILD: 8.0, t_stim: 0.334592632507573
# In iter_num: 44727, ABL: 40, ILD: -8.0, t_stim: 0.26960934281188
# In iter_num: 49905, ABL: 60, ILD: -2.0, t_stim: 0.258662424993083
# In iter_num: 49995, ABL: 60, ILD: 4.0, t_stim: 0.302669596861398
# In iter_num: 49980, ABL: 60, ILD: 8.0, t_stim: 1.03125013531203
# In iter_num: 44730, ABL: 40, ILD: 1.0, t_stim: 0.817475658183679
# In iter_num: 49944, ABL: 40, ILD: -8.0, t_stim: 0.44965766557985
# In iter_num: 45237, ABL: 60, ILD: -4.0, t_stim: 0.420840045333668
# In iter_num: 44733, ABL: 60, ILD: -4.0, t_stim: 0.670836431921936
# In iter_num: 49956, ABL: 20, ILD: -2.0, t_stim: 0.529098070640573
# In iter_num: 49983, ABL: 20, ILD: -4.0, t_stim: 1.14067366767145
# In iter_num: 44736, ABL: 20, ILD: 16.0, t_stim: 0.585588692019583
# In iter_num: 45240, ABL: 20, ILD: 1.0, t_stim: 0.366874746127577
# In iter_num: 44739, ABL: 60, ILD: 1.0, t_stim: 0.683069330913063
# In iter_num: 45243, ABL: 60, ILD: -16.0, t_stim: 0.962556510280889
# In iter_num: 45246, ABL: 60, ILD: 2.0, t_stim: 0.371342643181136
# In iter_num: 45249, ABL: 20, ILD: 4.0, t_stim: 0.249281626979926

# %% [markdown]
# ## valid rt wrt stim

# %%
plt.figure(figsize=(15,10))
rt_wrt_stim = [res['rt'] - res['t_stim'] for res in sim_results if res['rt'] > res['t_stim']]
bins = np.arange(0, 2, 0.01)
plt.hist(rt_wrt_stim, bins=bins, density=True, histtype='step', label='vp params');

data_rt_wrt_stim = df_1['timed_fix'] - df_1['intended_fix']
plt.hist(data_rt_wrt_stim, bins=bins, density=True, histtype='step', color='red', label='data');
plt.xlabel('RT - Stimulus (s)');    
plt.ylabel('Density');
plt.legend();
plt.title('valid rt wrt stim')
# plt.xlim(-1,1)
plt.grid(True)
plt.xlim(0,0.4)
xticks = np.arange(0, 0.4, 0.01)
plt.xticks(xticks, [f'{x:.2f}' for x in xticks]);

# %% [markdown]
# ## valid rt wrt fix

# %%
rt = [res['rt'] for res in sim_results if res['rt'] > res['t_stim']]
data_rt = df_1['timed_fix']

bins = np.arange(0, 2, 0.01)
plt.hist(rt, bins=bins, density=True, histtype='step', label='vp params');
plt.hist(data_rt, bins=bins, density=True, histtype='step', color='red', label='data');

plt.xlabel('RT (s) wrt fix');
plt.ylabel('Density');
plt.legend();
plt.title('valid rt wrt fix')
# Out:
# Text(0.5, 1.0, 'valid rt wrt fix')

# %% [markdown]
# ## all rt wrt fix

# %%
all_rt = [res['rt'] for res in sim_results]
df_led_off = df [ df['LED_trial'] == 0]
df_led_off_all_rt = df_led_off['timed_fix']

bins = np.arange(0, 2, 0.01)
plt.hist(all_rt, bins=bins, density=True, histtype='step', label='vp params');
plt.hist(df_led_off_all_rt, bins=bins, density=True, histtype='step', color='red', label='data');
plt.legend();
plt.xlabel('all rt wrt fix')
plt.ylabel('Density');
plt.title('all rt inclding aborts wrt fix')
# Out:
# Text(0.5, 1.0, 'all rt inclding aborts wrt fix')

# %% [markdown]
# # all rt wrt fix, trunc aborts removed

# %%
all_rt = [res['rt'] for res in sim_results if not(res['rt'] < res['t_stim'] and res['rt'] > 0.3)]

df_led_off = df [ df['LED_trial'] == 0]
df_led_off = df_led_off[~((df_led_off['timed_fix'] > 0.3) & (df_led_off['timed_fix'] < df_led_off['intended_fix']))]
df_led_off_all_rt = df_led_off['timed_fix']

bins = np.arange(0, 2, 0.01)
plt.hist(all_rt, bins=bins, density=True, histtype='step', label='vp params');
plt.hist(df_led_off_all_rt, bins=bins, density=True, histtype='step', color='red', label='data');
plt.legend();
plt.xlabel('all rt wrt fix')
plt.ylabel('Density');
plt.title('all rt with truncated aborts removed, wrt fix');

# %% [markdown]
# ## all rt wrt stim

# %%
all_rt = [res['rt'] - res['t_stim'] for res in sim_results]
df_led_off = df [ df['LED_trial'] == 0]
df_led_off_all_rt = df_led_off['timed_fix'] - df_led_off['intended_fix']

bins = np.arange(-1, 1, 0.01)
plt.hist(all_rt, bins=bins, density=True, histtype='step', label='vp params');
plt.hist(df_led_off_all_rt, bins=bins, density=True, histtype='step', color='red', label='data', ls='--');
plt.legend();
plt.xlabel('all rt wrt stim')
plt.ylabel('Density');
plt.title('all rt wrt stim');

# %% [markdown]
# # all rt wrt stim trunc aborts removed

# %%
all_rt = [res['rt'] - res['t_stim'] for res in sim_results if not(res['rt'] < res['t_stim'] and res['rt'] > 0.3)]

df_led_off = df [ df['LED_trial'] == 0]
df_led_off = df_led_off[~((df_led_off['timed_fix'] > 0.3) & (df_led_off['timed_fix'] < df_led_off['intended_fix']))]
df_led_off_all_rt = df_led_off['timed_fix'] - df_led_off['intended_fix']

bins = np.arange(-1, 1, 0.01)
plt.hist(all_rt, bins=bins, density=True, histtype='step', label='vp params');
plt.hist(df_led_off_all_rt, bins=bins, density=True, histtype='step', color='red', label='data');
plt.legend();
plt.xlabel('all rt wrt stim')
plt.ylabel('Density');
plt.title('all rt with truncated aborts removed, wrt stim');

# %% [markdown]
# ## psychometric

# %%
sim_results_df = pd.DataFrame(sim_results)
sim_results_valid_df = sim_results_df[ sim_results_df['rt'] > sim_results_df['t_stim'] ]
sim_results_valid_df = sim_results_valid_df.copy()

sim_results_valid_df.loc[:, 'RHS'] = (sim_results_valid_df['choice'] > 0).astype(int)
sim_grouped = sim_results_valid_df.groupby('ILD')['RHS'].mean().reset_index()

# data
data_df = df_1.copy()
data_df.loc[:, 'RHS'] = (data_df['response_poke'] == 3).astype(int)
data_grouped = data_df.groupby('ILD')['RHS'].mean().reset_index()

plt.plot(data_grouped['ILD'], data_grouped['RHS'], label='data', marker='o', color='red');
plt.plot(sim_grouped['ILD'], sim_grouped['RHS'], label='vp params', marker='o');
plt.xlabel('ILD (dB)');
plt.ylabel('P(RHS)');
plt.legend();

# %% [markdown]
# ## tachometric

# %%
bins = np.arange(0, 1, 0.01)
bin_centers = bins[:-1] + (bins[1] - bins[0]) / 2

# sim results
sim_results_df = pd.DataFrame(sim_results)
sim_results_valid_df = sim_results_df[ sim_results_df['rt'] > sim_results_df['t_stim'] ].copy()
sim_results_valid_df.loc[:, 'correct'] = (sim_results_valid_df['choice'] * sim_results_valid_df['ILD'] > 0)
sim_results_valid_df.loc[:, 'rt_wrt_stim'] = sim_results_valid_df['rt'] - sim_results_valid_df['t_stim']

sim_results_valid_df['rt_bin'] = pd.cut(sim_results_valid_df['rt_wrt_stim'], bins=bins, right=False)
sim_grouped = sim_results_valid_df.groupby('rt_bin')['correct'].mean().reset_index()

plt.plot(bin_centers, sim_grouped['correct'], linestyle='-', label='sim', color='b')

# data
data_df = df_1.copy()
data_df.loc[:, 'correct'] = ((2*data_df['response_poke'] - 5) * data_df['ILD'] > 0).astype(int)
data_df.loc[:, 'rt_wrt_stim'] = data_df['timed_fix'] - data_df['intended_fix']

data_df['rt_bin'] = pd.cut(data_df['rt_wrt_stim'], bins=bins, right=False)
data_grouped = data_df.groupby('rt_bin')['correct'].mean().reset_index()

plt.plot(bin_centers, data_grouped['correct'], linestyle='-', label=' data', color='r')
plt.xlabel('RT - Stimulus (s)');
plt.ylabel('P(Correct)');
plt.legend();
# Out:
# /tmp/ipykernel_564472/464138592.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sim_grouped = sim_results_valid_df.groupby('rt_bin')['correct'].mean().reset_index()
# /tmp/ipykernel_564472/464138592.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data_grouped = data_df.groupby('rt_bin')['correct'].mean().reset_index()

# %% [markdown]
# # tachometric ABL wise

# %%
bins = np.arange(0, 1, 0.01)
bin_centers = bins[:-1] + (bins[1] - bins[0]) / 2

plt.figure(figsize=(20, 5))

ABL_values = np.sort(df_1['ABL'].unique())
colors = ['b', 'g', 'r']  # You can pick your own color scheme
a = 1
for abl_val, c in zip(ABL_values, colors):
    plt.subplot(1, len(ABL_values), a)
    # --- 1) Filter SIM dataframe for the given ABL value ---
    sim_sub = sim_results_valid_df[sim_results_valid_df['ABL'] == abl_val].copy()
    # Bin the RT values
    sim_sub['rt_bin'] = pd.cut(sim_sub['rt_wrt_stim'], bins=bins, right=False)
    # Group by bins, compute mean correctness
    sim_grouped = sim_sub.groupby('rt_bin', observed=False)['correct'].mean().reset_index()
    
    # Plot SIM result (solid line)
    plt.plot(bin_centers, sim_grouped['correct'], 
            linestyle='-', 
            color=c, 
            label=f'Sim ABL={abl_val}')
    
    # --- 2) Filter DATA dataframe for the given ABL value ---
    data_sub = data_df[data_df['ABL'] == abl_val].copy()
    # Bin the RT values
    data_sub['rt_bin'] = pd.cut(data_sub['rt_wrt_stim'], bins=bins, right=False)
    # Group by bins, compute mean correctness
    data_grouped = data_sub.groupby('rt_bin', observed=False)['correct'].mean().reset_index()
    
    # Plot DATA result (dashed line)
    plt.plot(bin_centers, data_grouped['correct'], 
            linestyle='--', 
            color=c, 
            label=f'Data ABL={abl_val}')

        # Cosmetics
    plt.xlabel('RT - Stimulus (s)')
    plt.ylabel('P(Correct)')
    plt.ylim([0.3, 1])  # If you want to fix y-limits
    plt.xlim(0, 0.5)
    plt.legend()
    a += 1

# %% [markdown]
# # investigate second bump

# %%
low_rt = 0.2
high_rt = 0.3

# Filter the dataframe based on that range:
df_second_bump = data_df[
    (data_df["rt_wrt_stim"] >= low_rt) & 
    (data_df["rt_wrt_stim"] <= high_rt)
]


plt.figure(figsize=(20, 5))
plt.subplot(1,3,1)
# plt.hist(df_second_bump["ABL"], bins=[20, 40, 60], label='Data')
counts = df_second_bump["ABL"].value_counts()
counts.plot(kind="bar", edgecolor="black")

plt.xlabel('ABL')

plt.subplot(1,3,2)
counts = np.abs(df_second_bump["ILD"]).value_counts()
counts.plot(kind="bar", edgecolor="black")
plt.xlabel('ILD')

plt.subplot(1,3,3)
plt.hist(df_second_bump["intended_fix"], bins=50, label='Data', histtype='step', density=True)
plt.hist(data_df["intended_fix"], bins=50, label='All Data', histtype='step', density=True)
plt.legend();
plt.xlabel('Intended Fixation Time')

plt.suptitle('Second Bump Data Distribution')
# Out:
# Text(0.5, 0.98, 'Second Bump Data Distribution')

# %%
# Assuming `trial` column in df_second_bump contains integer values
# Create a list of trials minus 1
trial_minus_1 = df_second_bump['trial'] - 1

# Filter rows from df_1 where the trial column matches the values in trial_minus_1
filtered_df = og_df[og_df['trial'].isin(trial_minus_1)]

# Display the filtered dataframe
abort_event = filtered_df['abort_event']

abort_event_counts = abort_event.value_counts()
abort_event_counts.plot(kind="bar", edgecolor="black")
plt.title(f'Abort event count of trial - 1 for second bump data btn {low_rt} and {high_rt} s')
# Out:
# Text(0.5, 1.0, 'Abort event count of trial - 1 for second bump data btn 0.2 and 0.3 s')

# %%
# Ensure the DataFrame index is reset to align with row positions
df = df.reset_index(drop=True)

# Create a mask to identify rows where the conditions are met
mask = df.apply(
    lambda row: (
        row['trial'] > 1  # Ensure trial-1 is a valid index
        and (row['trial'] - 1) in df.index  # Check trial-1 exists in the DataFrame index
        and df.iloc[int(row['trial']) - 1]['abort_event'] == 3  # Check abort_event in trial-1
        and row['ABL'] == df.iloc[int(row['trial']) - 1]['ABL']  # Match ABL with trial-1
        and row['ILD'] == df.iloc[int(row['trial']) - 1]['ILD']  # Match ILD with trial-1
        and row['success'] == 1
    ),
    axis=1
)

# Remove the rows that meet the condition
df_removed_repeats = df[~mask]

# %%
df_removed_repeats_led_off_valid_trials = df_removed_repeats[ (df_removed_repeats['LED_trial'] == 0) & \
                                                             (df_removed_repeats['success'] == 1) ]

# %%
rt_wrt_stim_df_non_repeat = df_removed_repeats_led_off_valid_trials['timed_fix'] \
    - df_removed_repeats_led_off_valid_trials['intended_fix']

bins = np.arange(0, 1, 0.01)
plt.hist(rt_wrt_stim_df_non_repeat, bins=bins, density=True, histtype='step', label='data');
plt.title('valid rt wrt stim, no repeat trials')
plt.xlabel('RT - Stimulus (s)');
plt.ylabel('Density');

# %% [markdown]
# # see animal wise

# %%
bins = np.arange(0, 1, 0.01)
bin_centers = bins[:-1] + (bins[1] - bins[0]) / 2

animals = df_1['animal'].unique()
plt.figure(figsize=(20, 5))
a = 1

for animal in animals:
    animal_data = df_1[ df_1['animal'] == animal ]
    animal_rt_wrt_stim = animal_data['timed_fix'] - animal_data['intended_fix']
    plt.subplot(1, len(animals), a)
    plt.hist(animal_rt_wrt_stim, bins=bins, density=True, histtype='step', label='data');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('Density');
    plt.title(f'valid rt wrt stim, Animal={animal}')
    a += 1

# %%
except_animals = [92, 93, 98]
df_1_except = df_1[ ~df_1['animal'].isin(except_animals) ]

df_1_except_animals_rt_wrt_stim = df_1_except['timed_fix'] - df_1_except['intended_fix']
df_1_rt_wrt_stim = df_1['timed_fix'] - df_1['intended_fix']

bins = np.arange(0, 1, 0.01)
plt.hist(df_1_rt_wrt_stim, bins=bins, density=True, histtype='step', label='all', ls='--');
plt.hist(df_1_except_animals_rt_wrt_stim, bins=bins, density=True, histtype='step', label=f'removed except {except_animals}');
plt.xlabel('RT - Stimulus (s)');
plt.ylabel('Density');
plt.title(f'valid rt wrt stim, except {except_animals}');
plt.legend();

# %% [markdown]
# # df led on also?

# %%
df_led_on = df [ df['LED_trial'] == 1 ]
df_led_on_valid_trials = df_led_on[ df_led_on['success'] == 1 ]
led_on_rt_wrt_stim = df_led_on_valid_trials['timed_fix'] - df_led_on_valid_trials['intended_fix']

led_off_rt_wrt_stim = df_1['timed_fix'] - df_1['intended_fix']

bins = np.arange(0, 1, 0.01)
plt.hist(led_on_rt_wrt_stim, bins=bins, density=True, histtype='step', label='LED ON', color='r');
plt.hist(led_off_rt_wrt_stim, bins=bins, density=True, histtype='step', label='LED OFF', color='b', alpha=0.6);
plt.xlabel('RT - Stimulus (s)');
plt.ylabel('Density');
plt.legend();
plt.title('all animals valid rt wrt stim');

# %%
# animal wise LED on

animals = df_led_on['animal'].unique()
plt.figure(figsize=(20, 5))
a = 1
for animal in animals:
    animal_data = df_led_on_valid_trials[ df_led_on_valid_trials['animal'] == animal ]
    animal_rt_wrt_stim = animal_data['timed_fix'] - animal_data['intended_fix']
    plt.subplot(1, len(animals), a)
    plt.hist(animal_rt_wrt_stim, bins=bins, density=True, histtype='step', label='data');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('density')
    plt.title(f'ON,  Animal={animal}')
    a += 1

# %% [markdown]
# # plot RTs as func of ABL

# %%
plt.figure(figsize=(20, 5))
a = 1
for ABL in ABL_arr:
    ABL_data = df_1[ df_1['ABL'] == ABL ]
    ABL_rt_wrt_stim = ABL_data['timed_fix'] - ABL_data['intended_fix']
    plt.subplot(1, len(ABL_arr), a)
    plt.hist(ABL_rt_wrt_stim, bins=bins, density=True, histtype='step', label='data');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('density')
    plt.title(f'ABL={ABL}')
    a += 1

# %%
bins = np.arange(0, 1, 0.01)
plt.figure(figsize=(10,30))
a = 1
pos_ILD = np.sort(np.unique(np.abs(ILD_arr)))
for ILD in pos_ILD:
    ILD_data = df_1[ (df_1['ILD'] == ILD) | (df_1['ILD'] == -ILD) ]
    for ABL in ABL_arr:
        plt.subplot(5, 3, a)

        ABL_data = ILD_data[ ILD_data['ABL'] == ABL ]
        ABL_rt_wrt_stim = ABL_data['timed_fix'] - ABL_data['intended_fix']
        plt.hist(ABL_rt_wrt_stim, bins=bins, density=True, histtype='step', label=f'ABL={ABL}');
        plt.xlabel('RT - Stimulus (s)');
        plt.ylabel('density')
        plt.title(f'abs ILD={ILD}')
        plt.legend();
        a += 1

# %%
bins = np.arange(0, 1, 0.01)
plt.figure(figsize=(20,5))
a = 1
pos_ILD = np.sort(np.unique(np.abs(ILD_arr)))
for ILD in pos_ILD:
    ILD_data = df_1[ (df_1['ILD'] == ILD) | (df_1['ILD'] == -ILD) ]
    plt.subplot(1,6, a)
    for ABL in ABL_arr:
        ABL_data = ILD_data[ ILD_data['ABL'] == ABL ]
        ABL_rt_wrt_stim = ABL_data['timed_fix'] - ABL_data['intended_fix']
        plt.hist(ABL_rt_wrt_stim, bins=bins, density=True, histtype='step', label=f'ABL={ABL}');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('density')
    plt.title(f'abs ILD={ILD}')
    plt.legend();
    a += 1

# %%
bins = np.arange(0, 1, 0.01)
plt.figure(figsize=(10,15))
a = 1
pos_ILD = np.sort(np.unique(np.abs(ILD_arr)))
for ABL in ABL_arr:
    ABL_data = df_1[ df_1['ABL'] == ABL ]
    plt.subplot(3,1, a)
    for ILD in pos_ILD:
        ILD_data = ABL_data[ (ABL_data['ILD'] == ILD) | (ABL_data['ILD'] == -ILD) ]
        ILD_rt_wrt_stim = ILD_data['timed_fix'] - ILD_data['intended_fix']
        plt.hist(ILD_rt_wrt_stim, bins=bins, density=True, histtype='step', label=f'ILD={ILD}');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('density')
    plt.title(f'abs ABL={ABL}')
    a += 1

# %% [markdown]
# # all animals on and off

# %%
animals = df_1['animal'].unique()
a = 1
plt.figure(figsize=(20, 5))
for animal in animals:
    animal_data = df[ df['animal'] == animal ]
    animal_on = animal_data[ animal_data['LED_trial'] == 1 ]
    animal_off = animal_data[ animal_data['LED_trial'] == 0 ]

    animal_on_valid = animal_on[ animal_on['success'] == 1 ]
    animal_off_valid = animal_off[ animal_off['success'] == 1 ]

    animal_on_valid_rt_wrt_stim = animal_on_valid['timed_fix'] - animal_on_valid['intended_fix']
    animal_off_valid_rt_wrt_stim = animal_off_valid['timed_fix'] - animal_off_valid['intended_fix']

    plt.subplot(1, len(animals), a)
    plt.hist(animal_on_valid_rt_wrt_stim, bins=bins, density=True, histtype='step', label='LED ON', color='r');
    plt.hist(animal_off_valid_rt_wrt_stim, bins=bins, density=True, histtype='step', label='LED OFF', color='b');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('Density');
    plt.legend();
    plt.title(f'Animal={animal}')

    a += 1

# %%
animals = df_1['animal'].unique()
a = 1
plt.figure(figsize=(20, 5))
for animal in animals:
    animal_data = df[ df['animal'] == animal ]
    animal_on = animal_data[ animal_data['LED_trial'] == 1 ]
    animal_off = animal_data[ animal_data['LED_trial'] == 0 ]

    animal_on_valid = animal_on[ animal_on['success'] == 1 ]
    animal_off_valid = animal_off[ animal_off['success'] == 1 ]

    animal_on_valid_rt_wrt_stim = animal_on_valid['timed_fix'] - animal_on_valid['intended_fix']
    animal_off_valid_rt_wrt_stim = animal_off_valid['timed_fix'] - animal_off_valid['intended_fix']
    plt.subplot(1, len(animals), a)
    # hist on - hist off
    hist_on, _ = np.histogram(animal_on_valid_rt_wrt_stim, bins=bins, density=True)
    hist_off, _ = np.histogram(animal_off_valid_rt_wrt_stim, bins=bins, density=True)

    plt.plot(bins[:-1], hist_on - hist_off, label='LED ON - LED OFF');
    plt.xlabel('RT - Stimulus (s)');
    plt.ylabel('Density');
    plt.legend();
    plt.title(f'Animal={animal}')

    a += 1
